# %%
# !pip install -q six numpy scipy matplotlib scikit-image opencv-python imageio
# !pip install -q keras imgaug
# !pip install -q keras

# %%
import keras
import imgaug as ia
from imgaug import augmenters as iaa
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import SGD
from keras.callbacks import *
from keras.models import load_model


# from keras.callbacks import LearningRateScheduler,ModelCheckpoint,EarlyStopping,LambdaCallback
import os,sys,math

# %%
import google
colab_dir='./'
file_name='EIP_CIFAR_10'
if hasattr(google,'colab'):
    from google.colab import drive
    drive.mount('/content/gdrive')
    colab_dir='/content/gdrive/My Drive/Colab Notebooks/'
model_file=colab_dir+file_name+'.h5'

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
#Augmentation and resizing
#augment and then concat samples with original
def augment(dataset,flip=0.5,blur=1.0):
    ia.seed(1)
#     seq = iaa.Sequential([iaa.Fliplr(flip),iaa.GaussianBlur(sigma=(0, blur)),iaa.Sometimes(iaa.Crop(percent=(0, 0.1))),
#                          iaa.Sometimes(iaa.Affine(scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
#                                              translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
#                                              rotate=(-45, 45),shear=(-16, 16),order=[0, 1],cval=(0, 255),mode=ia.ALL))])
    seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0, 0.1)),
    iaa.Sometimes(0.5,
        iaa.GaussianBlur(sigma=(0, 0.5))
    ),
    iaa.ContrastNormalization((0.75, 1.5)),
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5),
    iaa.Multiply((0.8, 1.2), per_channel=0.2),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8))], random_order=True)    
    return seq.augment_images(dataset)

def augmenter(X,y,start=0,end=1):
    ln=len(X)
    print('Before augmentation:',X.shape,y.shape)
    start=int(start*ln)
    end=int(end*ln)
    new_X=augment(X)[start:end]
    new_y=y[start:end]
    X=np.concatenate((X,new_X))
    y=np.concatenate((y,new_y))
    print('After augmentation:',X.shape,y.shape)
    return (X,y)

#26x26 is almost half of 32x32. 22x22 maybe too small even though its exact half.
def resize_imgs(imgs,shape=(26,26)):
    seq = iaa.Sequential([iaa.Scale({"height": shape[0], "width": shape[1]})])
    return seq.augment_images(imgs)

# %%
# Dense Block
def add_denseblock(input, num_filter = 12, dropout_rate = 0.2,num_layers=12):
    global compression
    temp = input
    for _ in range(num_layers):
        BatchNorm = BatchNormalization()(temp)
        relu = Activation('relu')(BatchNorm)
        Conv2D_3_3 = Conv2D(int(num_filter*compression), (3,3),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
        if dropout_rate>0:
            Conv2D_3_3 = Dropout(dropout_rate)(Conv2D_3_3)
        concat = Concatenate(axis=-1)([temp,Conv2D_3_3])        
        temp = concat        
    return temp

def add_transition(input, num_filter = 12, dropout_rate = 0.2):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    Conv2D_BottleNeck = Conv2D(int(num_filter*compression), (1,1),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
    if dropout_rate>0:
        Conv2D_BottleNeck = Dropout(dropout_rate)(Conv2D_BottleNeck)
    avg = AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)    
    return avg

def output_layer(input):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    AvgPooling = AveragePooling2D(pool_size=(2,2))(relu)
    flat = Flatten()(AvgPooling)
    output = Dense(num_classes, activation='softmax')(flat)    
    return output
  
def dense_unit(input_layer,num_filter, dropout_rate,num_layers):
    dense_block=add_denseblock(input_layer, num_filter, dropout_rate,num_layers)
    transition_block=add_transition(dense_block, num_filter, dropout_rate)
    return transition_block
  
def dense_units_chain(n,input_layer,num_filter, dropout_rate,num_layers):
    dense_unit_=input_layer
    for i in range(n):
        dense_unit_=dense_unit(dense_unit_,num_filter, dropout_rate,num_layers)
    return dense_unit_

# %%
#callback classes
#try building model with clr, snapshot ensemble

class CyclicLR(Callback):
    "source: https://github.com/bckenstler/CLR/blob/master/clr_callback.py"
    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())
        
###################################################################################################
###################################################################################################
class SnapshotModelCheckpoint(Callback):
    """source : https://github.com/titu1994/Snapshot-Ensembles/blob/master/snapshot.py"""
    def __init__(self, nb_epochs, nb_snapshots, fn_prefix='Model'):
        super(SnapshotModelCheckpoint, self).__init__()

        self.check = nb_epochs // nb_snapshots
        self.fn_prefix = fn_prefix

    def on_epoch_end(self, epoch, logs={}):
        if epoch != 0 and (epoch + 1) % self.check == 0:
            filepath = self.fn_prefix + "-%d.h5" % ((epoch + 1) // self.check)
            self.model.save_weights(filepath, overwrite=True)
            #print("Saved snapshot at weights/%s_%d.h5" % (self.fn_prefix, epoch))


class SnapshotCallbackBuilder:
    def __init__(self, nb_epochs, nb_snapshots, init_lr=0.1):
        self.T = nb_epochs
        self.M = nb_snapshots
        self.alpha_zero = init_lr

    def get_callbacks(self, model_prefix='Model'):
        """
        Creates a list of callbacks that can be used during training to create a
        snapshot ensemble of the model.
        Args:
            model_prefix: prefix for the filename of the weights.
        Returns: list of 3 callbacks [ModelCheckpoint, LearningRateScheduler,
                 SnapshotModelCheckpoint] which can be provided to the 'fit' function
        """
        if not os.path.exists('weights/'):
            os.makedirs('weights/')

        callback_list = [callbacks.ModelCheckpoint("weights/%s-Best.h5" % model_prefix, monitor="val_acc",
                                                    save_best_only=True, save_weights_only=True),
                         callbacks.LearningRateScheduler(schedule=self._cosine_anneal_schedule),
                         SnapshotModelCheckpoint(self.T, self.M, fn_prefix='weights/%s' % model_prefix)]

        return callback_list

    def _cosine_anneal_schedule(self, t):
        cos_inner = np.pi * (t % (self.T // self.M))  # t - 1 is used when t has 1-based indexing.
        cos_inner /= self.T // self.M
        cos_out = np.cos(cos_inner) + 1
        return float(self.alpha_zero / 2 * cos_out)

# %%
def load_prev_model(model_small=None):
#     print(os.popen('du -sh '+colab_dir+'*').read())
    last_best=os.popen('du -sh '+colab_dir+r'*|sed -r "s/^[0-9\.]+[MK]?\s(.*)$/\1/g;"|tail -1').read().strip()
    model_prev=None
    try:
        print('Attempting to load last best model from file - ',end='')
        last_best_fn=last_best.split('/')[-1]
        last_best_epoch=last_best_fn.split('.')[1].split('-')[0]
        model_prev=load_model(last_best)
        print('Sucess\nLoaded '+last_best_fn, 'epoch :', last_best_epoch)
    except Exception as e:
        print('Failed!\n',e)
        try:
            print('Attempting to load last saved model from file - ',end='')
            model_prev = load_model(model_file)
            print('Sucess\nLoaded model from file',model_file)
        except Exception as e:
    #         print(str(e), 'at line ', sys.exc_info()[2].tb_lineno)
            print('Failed!\n',e)
            try:
                print('Attempting to load in memory, small model - ',end='')
                if len(model_small.layers)>1:
                    model_prev=model_small
                print('Sucess')
            except Exception as e:
                print('Failed!\n',e)
    return model_prev

# %%
def copy_weights(model_to,model_from):
    #model_to.set_weights(model_from.get_weights())
    s,err=0,0
    print('Trying to copy weights')
    try:
        if len(model_to.layers) >1 and len(model_from.layers) >1:
            pass
    except Exception as e:
        print('Inavlid models',model_to,model_from)
        return
    for new_layer, layer in zip(model_to.layers[1:], model_from.layers[1:]):
        s+=1
        try:
            new_layer.set_weights(layer.get_weights())
        except Exception as e:
            pass
    print('Done: errors:',err)
      
#new model with larger i/p layer
def larger_model(src_model,shape=(32,32,3)):
    new_input=Input(shape)
    src_model.layers.pop(0)
    new_output=src_model(new_input)
    new_model=Model(new_input,new_output)
    return new_model

# Load CIFAR10 Data
def load_data(resize=False,shape=(26,26),test_augment=False):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    
    if resize:
        x_train=resize_imgs(x_train,shape)
        x_test=resize_imgs(x_test,shape)
    
    (x_train, y_train) = augmenter(x_train, y_train,end=1)
    if test_augment:
        (x_test, y_test) = augmenter(x_test, y_test,end=1)
    return (x_train, y_train,x_test, y_test)
#create a dnn model
def create_model(input_shape,num_layers,input=None):
    print('Creating model with input shape',input_shape)
    if input is None:
        input = Input(input_shape)
    First_Conv2D = Conv2D(num_filter, (3,3), use_bias=False ,padding='same')(input)
    hidden_dense_blocks = dense_units_chain(n_dense_blocks,First_Conv2D,num_filter,dropout_rate,num_layers)
    Last_Block = add_denseblock(hidden_dense_blocks, num_filter, dropout_rate)
    output = output_layer(Last_Block)
    model = Model(inputs=[input], outputs=[output])
    return model

# %%
print('====================HYPER PARAMETERS====================')
# Out:
# ====================HYPER PARAMETERS====================

# %%
# Hyperparameters
batch_size = 128
num_classes = 10
max_epochs = 250
model_small_epochs=20
model_large_epochs1=100
model_large_epochs2=80

num_layers = 36
# layers_small=12
# layers_large=num_layers-layers_small
layers_large=layers_small=num_layers
num_filter = 12
compression = 0.5
dropout_rate = 0.2
n_dense_blocks = 3
smaller_input=(26,26,3)

# %%
print('====================BEGIN OF SMALLER MODEL====================')
# Out:
# ====================BEGIN OF SMALLER MODEL====================

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=True,shape=smaller_input[:-1])

#callbacks
model_checkpointer=ModelCheckpoint('small_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.1, max_lr=0.2,step_size=8*(len(y_train)/batch_size))

# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
callbacks = [clr, model_checkpointer]
# Out:
# Before augmentation: (50000, 26, 26, 3) (50000, 10)
# After augmentation: (100000, 26, 26, 3) (100000, 10)

# %%
#create model
model_small = create_model((x_train.shape[1:]),num_layers=layers_small)
model_small.compile(loss='categorical_crossentropy',metrics=['accuracy'],
              optimizer=SGD(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True))
model_small.summary()
# Out:
# Creating model with input shape (26, 26, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 26, 26, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 26, 26, 12)   324         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 26, 26, 12)   48          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 26, 26, 12)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 26, 26, 6)    648         activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 26, 26, 6)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 26, 26, 18)   0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 26, 26, 18)   72          concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 26, 26, 18)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 26, 26, 6)    972         activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 26, 26, 6)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 26, 26, 24)   0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 26, 26, 24)   96          concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 26, 26, 24)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 6)    1296        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 26, 26, 6)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 26, 26, 30)   0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 26, 26, 30)   120         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 26, 26, 30)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 26, 26, 6)    1620        activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 26, 26, 6)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 26, 26, 36)   0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 26, 26, 36)   144         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 26, 26, 36)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 26, 26, 6)    1944        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 26, 26, 6)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 26, 26, 42)   0           concatenate_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 26, 26, 42)   168         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 26, 26, 42)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 26, 26, 6)    2268        activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 26, 26, 6)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 26, 26, 48)   0           concatenate_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 26, 26, 48)   192         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 26, 26, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 26, 26, 6)    2592        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 26, 26, 6)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 26, 26, 54)   0           concatenate_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 26, 26, 54)   216         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 26, 26, 54)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 26, 26, 6)    2916        activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 26, 26, 6)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 26, 26, 60)   0           concatenate_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 26, 26, 60)   240         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 26, 26, 60)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 26, 26, 6)    3240        activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 26, 26, 6)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 26, 26, 66)   0           concatenate_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 26, 26, 66)   264         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 26, 26, 66)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 26, 26, 6)    3564        activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 26, 26, 6)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 26, 26, 72)   0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 26, 26, 72)   288         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 26, 26, 72)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 26, 26, 6)    3888        activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 26, 26, 6)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 26, 26, 78)   0           concatenate_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 26, 26, 78)   312         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 26, 26, 78)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 26, 26, 6)    4212        activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 26, 26, 6)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 26, 26, 84)   0           concatenate_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 26, 26, 84)   336         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 26, 26, 84)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 26, 26, 6)    4536        activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 26, 26, 6)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 26, 26, 90)   0           concatenate_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 26, 26, 90)   360         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 26, 26, 90)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 26, 26, 6)    4860        activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 26, 26, 6)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 26, 26, 96)   0           concatenate_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 26, 26, 96)   384         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 26, 26, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 26, 26, 6)    5184        activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 26, 26, 6)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 26, 26, 102)  0           concatenate_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 26, 26, 102)  408         concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 26, 26, 102)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 26, 26, 6)    5508        activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 26, 26, 6)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 26, 26, 108)  0           concatenate_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 26, 26, 108)  432         concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 26, 26, 108)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 26, 26, 6)    5832        activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 26, 26, 6)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 26, 26, 114)  0           concatenate_16[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 26, 26, 114)  456         concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 26, 26, 114)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 26, 26, 6)    6156        activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 26, 26, 6)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 26, 26, 120)  0           concatenate_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 26, 26, 120)  480         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 26, 26, 120)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 26, 26, 6)    6480        activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 26, 26, 6)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 26, 26, 126)  0           concatenate_18[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 26, 26, 126)  504         concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 26, 26, 126)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 26, 26, 6)    6804        activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 26, 26, 6)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 26, 26, 132)  0           concatenate_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 26, 26, 132)  528         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 26, 26, 132)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 26, 26, 6)    7128        activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 26, 26, 6)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 26, 26, 138)  0           concatenate_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 26, 26, 138)  552         concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 26, 26, 138)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 26, 26, 6)    7452        activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 26, 26, 6)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 26, 26, 144)  0           concatenate_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 26, 26, 144)  576         concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 26, 26, 144)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 26, 26, 6)    7776        activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 26, 26, 6)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 26, 26, 150)  0           concatenate_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 26, 26, 150)  600         concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 26, 26, 150)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 26, 26, 6)    8100        activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 26, 26, 6)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 26, 26, 156)  0           concatenate_23[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 26, 26, 156)  624         concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 26, 26, 156)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 26, 26, 6)    8424        activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 26, 26, 6)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 26, 26, 162)  0           concatenate_24[0][0]
#                                                                  dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 26, 26, 162)  648         concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 26, 26, 162)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 26, 26, 6)    8748        activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 26, 26, 6)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 26, 26, 168)  0           concatenate_25[0][0]
#                                                                  dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 26, 26, 168)  672         concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 26, 26, 168)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 26, 26, 6)    9072        activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 26, 26, 6)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 26, 26, 174)  0           concatenate_26[0][0]
#                                                                  dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 26, 26, 174)  696         concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 26, 26, 174)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 26, 26, 6)    9396        activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 26, 26, 6)    0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 26, 26, 180)  0           concatenate_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 26, 26, 180)  720         concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 26, 26, 180)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 26, 26, 6)    9720        activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 26, 26, 6)    0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 26, 26, 186)  0           concatenate_28[0][0]
#                                                                  dropout_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 26, 26, 186)  744         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 26, 26, 186)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 26, 26, 6)    10044       activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 26, 26, 6)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 26, 26, 192)  0           concatenate_29[0][0]
#                                                                  dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 26, 26, 192)  768         concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 26, 26, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 26, 26, 6)    10368       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 26, 26, 6)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 26, 26, 198)  0           concatenate_30[0][0]
#                                                                  dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 26, 26, 198)  792         concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 26, 26, 198)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 26, 26, 6)    10692       activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 26, 26, 6)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 26, 26, 204)  0           concatenate_31[0][0]
#                                                                  dropout_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 26, 26, 204)  816         concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 26, 26, 204)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 26, 26, 6)    11016       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 26, 26, 6)    0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 26, 26, 210)  0           concatenate_32[0][0]
#                                                                  dropout_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 26, 26, 210)  840         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 26, 26, 210)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 26, 26, 6)    11340       activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 26, 26, 6)    0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 26, 26, 216)  0           concatenate_33[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 26, 26, 216)  864         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 26, 26, 216)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 26, 26, 6)    11664       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 26, 26, 6)    0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 26, 26, 222)  0           concatenate_34[0][0]
#                                                                  dropout_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 26, 26, 222)  888         concatenate_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 26, 26, 222)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 26, 26, 6)    11988       activation_36[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 26, 26, 6)    0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 26, 26, 228)  0           concatenate_35[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 26, 26, 228)  912         concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 26, 26, 228)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 26, 26, 6)    1368        activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 26, 26, 6)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 13, 13, 6)    0           dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 13, 13, 6)    24          average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 13, 13, 6)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 13, 13, 6)    324         activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 13, 13, 6)    0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 13, 13, 12)   0           average_pooling2d_1[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 13, 13, 12)   48          concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 13, 13, 12)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 13, 13, 6)    648         activation_39[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 13, 13, 6)    0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 13, 13, 18)   0           concatenate_37[0][0]
#                                                                  dropout_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 13, 13, 18)   72          concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 13, 13, 18)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 13, 13, 6)    972         activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 13, 13, 6)    0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 13, 13, 24)   0           concatenate_38[0][0]
#                                                                  dropout_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 13, 13, 24)   96          concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 13, 13, 24)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 13, 13, 6)    1296        activation_41[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 13, 13, 6)    0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 13, 13, 30)   0           concatenate_39[0][0]
#                                                                  dropout_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 13, 13, 30)   120         concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 13, 13, 30)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 13, 13, 6)    1620        activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 13, 13, 6)    0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 13, 13, 36)   0           concatenate_40[0][0]
#                                                                  dropout_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 13, 13, 36)   144         concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 13, 13, 36)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 13, 13, 6)    1944        activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 13, 13, 6)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 13, 13, 42)   0           concatenate_41[0][0]
#                                                                  dropout_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 13, 13, 42)   168         concatenate_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 13, 13, 42)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 13, 13, 6)    2268        activation_44[0][0]
# ...
# conv2d_111 (Conv2D)             (None, 6, 6, 6)      11664       activation_110[0][0]
# __________________________________________________________________________________________________
# dropout_110 (Dropout)           (None, 6, 6, 6)      0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, 6, 6, 222)    0           concatenate_107[0][0]
#                                                                  dropout_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 6, 6, 222)    888         concatenate_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 6, 6, 222)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 6, 6, 6)      1332        activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_111 (Dropout)           (None, 6, 6, 6)      0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 3, 3, 6)      0           dropout_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 3, 3, 6)      24          average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 3, 3, 6)      0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 3, 3, 6)      324         activation_112[0][0]
# __________________________________________________________________________________________________
# dropout_112 (Dropout)           (None, 3, 3, 6)      0           conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_109 (Concatenate)   (None, 3, 3, 12)     0           average_pooling2d_3[0][0]
#                                                                  dropout_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 3, 3, 12)     48          concatenate_109[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 3, 3, 12)     0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 3, 3, 6)      648         activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 3, 3, 6)      0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# concatenate_110 (Concatenate)   (None, 3, 3, 18)     0           concatenate_109[0][0]
#                                                                  dropout_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 3, 3, 18)     72          concatenate_110[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 3, 3, 18)     0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 3, 3, 6)      972         activation_114[0][0]
# __________________________________________________________________________________________________
# dropout_114 (Dropout)           (None, 3, 3, 6)      0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# concatenate_111 (Concatenate)   (None, 3, 3, 24)     0           concatenate_110[0][0]
#                                                                  dropout_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 3, 3, 24)     96          concatenate_111[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 3, 3, 24)     0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 3, 3, 6)      1296        activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_115 (Dropout)           (None, 3, 3, 6)      0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# concatenate_112 (Concatenate)   (None, 3, 3, 30)     0           concatenate_111[0][0]
#                                                                  dropout_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 3, 3, 30)     120         concatenate_112[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 3, 3, 30)     0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 3, 3, 6)      1620        activation_116[0][0]
# __________________________________________________________________________________________________
# dropout_116 (Dropout)           (None, 3, 3, 6)      0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_113 (Concatenate)   (None, 3, 3, 36)     0           concatenate_112[0][0]
#                                                                  dropout_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 3, 3, 36)     144         concatenate_113[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 3, 3, 36)     0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 3, 3, 6)      1944        activation_117[0][0]
# __________________________________________________________________________________________________
# dropout_117 (Dropout)           (None, 3, 3, 6)      0           conv2d_118[0][0]
# __________________________________________________________________________________________________
# concatenate_114 (Concatenate)   (None, 3, 3, 42)     0           concatenate_113[0][0]
#                                                                  dropout_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 3, 3, 42)     168         concatenate_114[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 3, 3, 42)     0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 3, 3, 6)      2268        activation_118[0][0]
# __________________________________________________________________________________________________
# dropout_118 (Dropout)           (None, 3, 3, 6)      0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, 3, 3, 48)     0           concatenate_114[0][0]
#                                                                  dropout_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 3, 3, 48)     192         concatenate_115[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 3, 3, 48)     0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 3, 3, 6)      2592        activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_119 (Dropout)           (None, 3, 3, 6)      0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# concatenate_116 (Concatenate)   (None, 3, 3, 54)     0           concatenate_115[0][0]
#                                                                  dropout_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 3, 3, 54)     216         concatenate_116[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 3, 3, 54)     0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 3, 3, 6)      2916        activation_120[0][0]
# __________________________________________________________________________________________________
# dropout_120 (Dropout)           (None, 3, 3, 6)      0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# concatenate_117 (Concatenate)   (None, 3, 3, 60)     0           concatenate_116[0][0]
#                                                                  dropout_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 3, 3, 60)     240         concatenate_117[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 3, 3, 60)     0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 3, 3, 6)      3240        activation_121[0][0]
# __________________________________________________________________________________________________
# dropout_121 (Dropout)           (None, 3, 3, 6)      0           conv2d_122[0][0]
# __________________________________________________________________________________________________
# concatenate_118 (Concatenate)   (None, 3, 3, 66)     0           concatenate_117[0][0]
#                                                                  dropout_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 3, 3, 66)     264         concatenate_118[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 3, 3, 66)     0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 3, 3, 6)      3564        activation_122[0][0]
# __________________________________________________________________________________________________
# dropout_122 (Dropout)           (None, 3, 3, 6)      0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# concatenate_119 (Concatenate)   (None, 3, 3, 72)     0           concatenate_118[0][0]
#                                                                  dropout_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 3, 3, 72)     288         concatenate_119[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 3, 3, 72)     0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 3, 3, 6)      3888        activation_123[0][0]
# __________________________________________________________________________________________________
# dropout_123 (Dropout)           (None, 3, 3, 6)      0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# concatenate_120 (Concatenate)   (None, 3, 3, 78)     0           concatenate_119[0][0]
#                                                                  dropout_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 3, 3, 78)     312         concatenate_120[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 3, 3, 78)     0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 78)     0           activation_124[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 78)           0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           790         flatten_1[0][0]
# ==================================================================================================
# Total params: 743,122
# Trainable params: 716,278
# Non-trainable params: 26,844
# __________________________________________________________________________________________________

# %%
#train model
hs=model_small.fit(x_train, y_train, batch_size=batch_size,verbose=1,
                    epochs=model_small_epochs, callbacks=callbacks,
                    validation_data=(x_test, y_test))
model_small.save(model_file)
print('Saved model_small to disk')
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/20
# 100000/100000 [==============================] - 263s 3ms/step - loss: 1.8174 - acc: 0.3187 - val_loss: 1.6683 - val_acc: 0.4233
# Epoch 2/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 1.5073 - acc: 0.4485 - val_loss: 1.4352 - val_acc: 0.5095
#
# Epoch 00002: val_acc improved from -inf to 0.50950, saving model to small_weights.02-0.51.h5
# Epoch 3/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 1.3679 - acc: 0.5048 - val_loss: 1.1512 - val_acc: 0.6069
# Epoch 4/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 1.2670 - acc: 0.5458 - val_loss: 1.1967 - val_acc: 0.6086
#
# Epoch 00004: val_acc improved from 0.50950 to 0.60860, saving model to small_weights.04-0.61.h5
# Epoch 5/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 1.1870 - acc: 0.5761 - val_loss: 1.2417 - val_acc: 0.6074
# Epoch 6/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 1.1261 - acc: 0.5990 - val_loss: 1.3084 - val_acc: 0.6132
#
# Epoch 00006: val_acc improved from 0.60860 to 0.61320, saving model to small_weights.06-0.61.h5
# Epoch 7/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 1.0691 - acc: 0.6207 - val_loss: 1.0572 - val_acc: 0.6668
# Epoch 8/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 1.0231 - acc: 0.6376 - val_loss: 1.0483 - val_acc: 0.6607
#
# Epoch 00008: val_acc improved from 0.61320 to 0.66070, saving model to small_weights.08-0.66.h5
# Epoch 9/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.9819 - acc: 0.6536 - val_loss: 0.9176 - val_acc: 0.7030
# Epoch 10/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.9339 - acc: 0.6727 - val_loss: 1.0827 - val_acc: 0.6926
#
# Epoch 00010: val_acc improved from 0.66070 to 0.69260, saving model to small_weights.10-0.69.h5
# Epoch 11/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.8954 - acc: 0.6844 - val_loss: 0.9471 - val_acc: 0.7138
# Epoch 12/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.8653 - acc: 0.6973 - val_loss: 0.9183 - val_acc: 0.7234
#
# Epoch 00012: val_acc improved from 0.69260 to 0.72340, saving model to small_weights.12-0.72.h5
# Epoch 13/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.8359 - acc: 0.7071 - val_loss: 0.9316 - val_acc: 0.7243
# Epoch 14/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.8079 - acc: 0.7179 - val_loss: 0.8132 - val_acc: 0.7511
#
# Epoch 00014: val_acc improved from 0.72340 to 0.75110, saving model to small_weights.14-0.75.h5
# Epoch 15/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.7838 - acc: 0.7266 - val_loss: 0.9096 - val_acc: 0.7443
# Epoch 16/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.7613 - acc: 0.7339 - val_loss: 0.7247 - val_acc: 0.7816
#
# Epoch 00016: val_acc improved from 0.75110 to 0.78160, saving model to small_weights.16-0.78.h5
# Epoch 17/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.7494 - acc: 0.7381 - val_loss: 0.9233 - val_acc: 0.7432
# Epoch 18/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.7420 - acc: 0.7397 - val_loss: 0.9540 - val_acc: 0.7378
#
# Epoch 00018: val_acc did not improve from 0.78160
# Epoch 19/20
# 100000/100000 [==============================] - 236s 2ms/step - loss: 0.7354 - acc: 0.7434 - val_loss: 0.8642 - val_acc: 0.7490
# Epoch 20/20
# 100000/100000 [==============================] - 235s 2ms/step - loss: 0.7331 - acc: 0.7441 - val_loss: 0.7842 - val_acc: 0.7631
#
# Epoch 00020: val_acc did not improve from 0.78160
# Saved model_small to disk

# %%
print('====================END OF SMALLER MODEL====================')
# Out:
# ====================END OF SMALLER MODEL====================

# %%
print('====================BEGIN OF LARGER MODEL====================')
# Out:
# ====================BEGIN OF LARGER MODEL====================

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=False)
#callbacks
model_checkpointer=ModelCheckpoint('large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.1, max_lr=0.2,step_size=8*(len(y_train)/batch_size),mode='exp_range',gamma=0.99994)

# M = 6
# nb_epoch = T = 200
# alpha_zero = 0.1
# model_prefix = 'ensemble_'
# snapshot = SnapshotCallbackBuilder(T, M, alpha_zero) 
# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)

callbacks = [clr, model_checkpointer]
# Out:
# Before augmentation: (50000, 32, 32, 3) (50000, 10)
# After augmentation: (100000, 32, 32, 3) (100000, 10)

# %%
#create model
model_prev=load_prev_model(model_small)
model_large = create_model(x_train.shape[1:],num_layers=layers_large)
# model_large = larger_model(model_prev)
copy_weights(model_large,model_prev)
model_large.compile(loss='categorical_crossentropy',metrics=['accuracy'],
                    optimizer=SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True))
model_large.summary()
# Out:
# Attempting to load last best model from file - Failed!
#  list index out of range
# Attempting to load last saved model from file - Sucess
# Loaded model from file ./EIP_CIFAR_10.h5
# Creating model with input shape (32, 32, 3)
# Trying to copy weights
# Done: errors: 0
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 32, 32, 12)   324         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 32, 32, 12)   48          conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 32, 32, 12)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 32, 32, 6)    648         activation_125[0][0]
# __________________________________________________________________________________________________
# dropout_124 (Dropout)           (None, 32, 32, 6)    0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# concatenate_121 (Concatenate)   (None, 32, 32, 18)   0           conv2d_125[0][0]
#                                                                  dropout_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 32, 32, 18)   72          concatenate_121[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 32, 32, 18)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 6)    972         activation_126[0][0]
# __________________________________________________________________________________________________
# dropout_125 (Dropout)           (None, 32, 32, 6)    0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# concatenate_122 (Concatenate)   (None, 32, 32, 24)   0           concatenate_121[0][0]
#                                                                  dropout_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 32, 32, 24)   96          concatenate_122[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 32, 32, 24)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 32, 32, 6)    1296        activation_127[0][0]
# __________________________________________________________________________________________________
# dropout_126 (Dropout)           (None, 32, 32, 6)    0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# concatenate_123 (Concatenate)   (None, 32, 32, 30)   0           concatenate_122[0][0]
#                                                                  dropout_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 32, 32, 30)   120         concatenate_123[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 32, 32, 30)   0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 32, 32, 6)    1620        activation_128[0][0]
# __________________________________________________________________________________________________
# dropout_127 (Dropout)           (None, 32, 32, 6)    0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# concatenate_124 (Concatenate)   (None, 32, 32, 36)   0           concatenate_123[0][0]
#                                                                  dropout_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 32, 32, 36)   144         concatenate_124[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 32, 32, 36)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 32, 32, 6)    1944        activation_129[0][0]
# __________________________________________________________________________________________________
# dropout_128 (Dropout)           (None, 32, 32, 6)    0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# concatenate_125 (Concatenate)   (None, 32, 32, 42)   0           concatenate_124[0][0]
#                                                                  dropout_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 32, 32, 42)   168         concatenate_125[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 32, 32, 42)   0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 32, 32, 6)    2268        activation_130[0][0]
# __________________________________________________________________________________________________
# dropout_129 (Dropout)           (None, 32, 32, 6)    0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# concatenate_126 (Concatenate)   (None, 32, 32, 48)   0           concatenate_125[0][0]
#                                                                  dropout_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 32, 32, 48)   192         concatenate_126[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 32, 32, 48)   0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 32, 32, 6)    2592        activation_131[0][0]
# __________________________________________________________________________________________________
# dropout_130 (Dropout)           (None, 32, 32, 6)    0           conv2d_132[0][0]
# __________________________________________________________________________________________________
# concatenate_127 (Concatenate)   (None, 32, 32, 54)   0           concatenate_126[0][0]
#                                                                  dropout_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 32, 32, 54)   216         concatenate_127[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 32, 32, 54)   0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 32, 32, 6)    2916        activation_132[0][0]
# __________________________________________________________________________________________________
# dropout_131 (Dropout)           (None, 32, 32, 6)    0           conv2d_133[0][0]
# __________________________________________________________________________________________________
# concatenate_128 (Concatenate)   (None, 32, 32, 60)   0           concatenate_127[0][0]
#                                                                  dropout_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 32, 32, 60)   240         concatenate_128[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 32, 32, 60)   0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 32, 32, 6)    3240        activation_133[0][0]
# __________________________________________________________________________________________________
# dropout_132 (Dropout)           (None, 32, 32, 6)    0           conv2d_134[0][0]
# __________________________________________________________________________________________________
# concatenate_129 (Concatenate)   (None, 32, 32, 66)   0           concatenate_128[0][0]
#                                                                  dropout_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 32, 32, 66)   264         concatenate_129[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 32, 32, 66)   0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 32, 32, 6)    3564        activation_134[0][0]
# __________________________________________________________________________________________________
# dropout_133 (Dropout)           (None, 32, 32, 6)    0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# concatenate_130 (Concatenate)   (None, 32, 32, 72)   0           concatenate_129[0][0]
#                                                                  dropout_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 32, 32, 72)   288         concatenate_130[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 32, 32, 72)   0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 32, 32, 6)    3888        activation_135[0][0]
# __________________________________________________________________________________________________
# dropout_134 (Dropout)           (None, 32, 32, 6)    0           conv2d_136[0][0]
# __________________________________________________________________________________________________
# concatenate_131 (Concatenate)   (None, 32, 32, 78)   0           concatenate_130[0][0]
#                                                                  dropout_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 32, 32, 78)   312         concatenate_131[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 32, 32, 78)   0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 32, 32, 6)    4212        activation_136[0][0]
# __________________________________________________________________________________________________
# dropout_135 (Dropout)           (None, 32, 32, 6)    0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# concatenate_132 (Concatenate)   (None, 32, 32, 84)   0           concatenate_131[0][0]
#                                                                  dropout_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 32, 32, 84)   336         concatenate_132[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 32, 32, 84)   0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 32, 32, 6)    4536        activation_137[0][0]
# __________________________________________________________________________________________________
# dropout_136 (Dropout)           (None, 32, 32, 6)    0           conv2d_138[0][0]
# __________________________________________________________________________________________________
# concatenate_133 (Concatenate)   (None, 32, 32, 90)   0           concatenate_132[0][0]
#                                                                  dropout_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 32, 32, 90)   360         concatenate_133[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 32, 32, 90)   0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 32, 32, 6)    4860        activation_138[0][0]
# __________________________________________________________________________________________________
# dropout_137 (Dropout)           (None, 32, 32, 6)    0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# concatenate_134 (Concatenate)   (None, 32, 32, 96)   0           concatenate_133[0][0]
#                                                                  dropout_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 32, 32, 96)   384         concatenate_134[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 32, 32, 96)   0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 32, 32, 6)    5184        activation_139[0][0]
# __________________________________________________________________________________________________
# dropout_138 (Dropout)           (None, 32, 32, 6)    0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# concatenate_135 (Concatenate)   (None, 32, 32, 102)  0           concatenate_134[0][0]
#                                                                  dropout_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 32, 32, 102)  408         concatenate_135[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 32, 32, 102)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 32, 32, 6)    5508        activation_140[0][0]
# __________________________________________________________________________________________________
# dropout_139 (Dropout)           (None, 32, 32, 6)    0           conv2d_141[0][0]
# __________________________________________________________________________________________________
# concatenate_136 (Concatenate)   (None, 32, 32, 108)  0           concatenate_135[0][0]
#                                                                  dropout_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 32, 32, 108)  432         concatenate_136[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 32, 32, 108)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 32, 32, 6)    5832        activation_141[0][0]
# __________________________________________________________________________________________________
# dropout_140 (Dropout)           (None, 32, 32, 6)    0           conv2d_142[0][0]
# __________________________________________________________________________________________________
# concatenate_137 (Concatenate)   (None, 32, 32, 114)  0           concatenate_136[0][0]
#                                                                  dropout_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 32, 32, 114)  456         concatenate_137[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 32, 32, 114)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 32, 32, 6)    6156        activation_142[0][0]
# __________________________________________________________________________________________________
# dropout_141 (Dropout)           (None, 32, 32, 6)    0           conv2d_143[0][0]
# __________________________________________________________________________________________________
# concatenate_138 (Concatenate)   (None, 32, 32, 120)  0           concatenate_137[0][0]
#                                                                  dropout_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 32, 32, 120)  480         concatenate_138[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 32, 32, 120)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 32, 32, 6)    6480        activation_143[0][0]
# __________________________________________________________________________________________________
# dropout_142 (Dropout)           (None, 32, 32, 6)    0           conv2d_144[0][0]
# __________________________________________________________________________________________________
# concatenate_139 (Concatenate)   (None, 32, 32, 126)  0           concatenate_138[0][0]
#                                                                  dropout_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 32, 32, 126)  504         concatenate_139[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 32, 32, 126)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 32, 32, 6)    6804        activation_144[0][0]
# __________________________________________________________________________________________________
# dropout_143 (Dropout)           (None, 32, 32, 6)    0           conv2d_145[0][0]
# __________________________________________________________________________________________________
# concatenate_140 (Concatenate)   (None, 32, 32, 132)  0           concatenate_139[0][0]
#                                                                  dropout_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 32, 32, 132)  528         concatenate_140[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 32, 32, 132)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 32, 32, 6)    7128        activation_145[0][0]
# __________________________________________________________________________________________________
# dropout_144 (Dropout)           (None, 32, 32, 6)    0           conv2d_146[0][0]
# __________________________________________________________________________________________________
# concatenate_141 (Concatenate)   (None, 32, 32, 138)  0           concatenate_140[0][0]
#                                                                  dropout_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 32, 32, 138)  552         concatenate_141[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 32, 32, 138)  0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 32, 32, 6)    7452        activation_146[0][0]
# __________________________________________________________________________________________________
# dropout_145 (Dropout)           (None, 32, 32, 6)    0           conv2d_147[0][0]
# __________________________________________________________________________________________________
# concatenate_142 (Concatenate)   (None, 32, 32, 144)  0           concatenate_141[0][0]
#                                                                  dropout_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 32, 32, 144)  576         concatenate_142[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 32, 32, 144)  0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 32, 32, 6)    7776        activation_147[0][0]
# __________________________________________________________________________________________________
# dropout_146 (Dropout)           (None, 32, 32, 6)    0           conv2d_148[0][0]
# __________________________________________________________________________________________________
# concatenate_143 (Concatenate)   (None, 32, 32, 150)  0           concatenate_142[0][0]
#                                                                  dropout_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 32, 32, 150)  600         concatenate_143[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 32, 32, 150)  0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 32, 32, 6)    8100        activation_148[0][0]
# __________________________________________________________________________________________________
# dropout_147 (Dropout)           (None, 32, 32, 6)    0           conv2d_149[0][0]
# __________________________________________________________________________________________________
# concatenate_144 (Concatenate)   (None, 32, 32, 156)  0           concatenate_143[0][0]
#                                                                  dropout_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 32, 32, 156)  624         concatenate_144[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 32, 32, 156)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 32, 32, 6)    8424        activation_149[0][0]
# __________________________________________________________________________________________________
# dropout_148 (Dropout)           (None, 32, 32, 6)    0           conv2d_150[0][0]
# __________________________________________________________________________________________________
# concatenate_145 (Concatenate)   (None, 32, 32, 162)  0           concatenate_144[0][0]
#                                                                  dropout_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 32, 32, 162)  648         concatenate_145[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 32, 32, 162)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 32, 32, 6)    8748        activation_150[0][0]
# __________________________________________________________________________________________________
# dropout_149 (Dropout)           (None, 32, 32, 6)    0           conv2d_151[0][0]
# __________________________________________________________________________________________________
# concatenate_146 (Concatenate)   (None, 32, 32, 168)  0           concatenate_145[0][0]
#                                                                  dropout_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 32, 32, 168)  672         concatenate_146[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 32, 32, 168)  0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 32, 32, 6)    9072        activation_151[0][0]
# __________________________________________________________________________________________________
# dropout_150 (Dropout)           (None, 32, 32, 6)    0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# concatenate_147 (Concatenate)   (None, 32, 32, 174)  0           concatenate_146[0][0]
#                                                                  dropout_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 32, 32, 174)  696         concatenate_147[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 32, 32, 174)  0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 32, 32, 6)    9396        activation_152[0][0]
# __________________________________________________________________________________________________
# dropout_151 (Dropout)           (None, 32, 32, 6)    0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# concatenate_148 (Concatenate)   (None, 32, 32, 180)  0           concatenate_147[0][0]
#                                                                  dropout_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 32, 32, 180)  720         concatenate_148[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 32, 32, 180)  0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 32, 32, 6)    9720        activation_153[0][0]
# __________________________________________________________________________________________________
# dropout_152 (Dropout)           (None, 32, 32, 6)    0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# concatenate_149 (Concatenate)   (None, 32, 32, 186)  0           concatenate_148[0][0]
#                                                                  dropout_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 32, 32, 186)  744         concatenate_149[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 32, 32, 186)  0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 32, 32, 6)    10044       activation_154[0][0]
# __________________________________________________________________________________________________
# dropout_153 (Dropout)           (None, 32, 32, 6)    0           conv2d_155[0][0]
# __________________________________________________________________________________________________
# concatenate_150 (Concatenate)   (None, 32, 32, 192)  0           concatenate_149[0][0]
#                                                                  dropout_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 32, 32, 192)  768         concatenate_150[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 32, 32, 192)  0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 32, 32, 6)    10368       activation_155[0][0]
# __________________________________________________________________________________________________
# dropout_154 (Dropout)           (None, 32, 32, 6)    0           conv2d_156[0][0]
# __________________________________________________________________________________________________
# concatenate_151 (Concatenate)   (None, 32, 32, 198)  0           concatenate_150[0][0]
#                                                                  dropout_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 32, 32, 198)  792         concatenate_151[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 32, 32, 198)  0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 6)    10692       activation_156[0][0]
# __________________________________________________________________________________________________
# dropout_155 (Dropout)           (None, 32, 32, 6)    0           conv2d_157[0][0]
# __________________________________________________________________________________________________
# concatenate_152 (Concatenate)   (None, 32, 32, 204)  0           concatenate_151[0][0]
#                                                                  dropout_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 32, 32, 204)  816         concatenate_152[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 32, 32, 204)  0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 32, 32, 6)    11016       activation_157[0][0]
# __________________________________________________________________________________________________
# dropout_156 (Dropout)           (None, 32, 32, 6)    0           conv2d_158[0][0]
# __________________________________________________________________________________________________
# concatenate_153 (Concatenate)   (None, 32, 32, 210)  0           concatenate_152[0][0]
#                                                                  dropout_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 32, 32, 210)  840         concatenate_153[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 32, 32, 210)  0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 32, 32, 6)    11340       activation_158[0][0]
# __________________________________________________________________________________________________
# dropout_157 (Dropout)           (None, 32, 32, 6)    0           conv2d_159[0][0]
# __________________________________________________________________________________________________
# concatenate_154 (Concatenate)   (None, 32, 32, 216)  0           concatenate_153[0][0]
#                                                                  dropout_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 32, 32, 216)  864         concatenate_154[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 32, 32, 216)  0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 32, 32, 6)    11664       activation_159[0][0]
# __________________________________________________________________________________________________
# dropout_158 (Dropout)           (None, 32, 32, 6)    0           conv2d_160[0][0]
# __________________________________________________________________________________________________
# concatenate_155 (Concatenate)   (None, 32, 32, 222)  0           concatenate_154[0][0]
#                                                                  dropout_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 32, 32, 222)  888         concatenate_155[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 32, 32, 222)  0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 32, 32, 6)    11988       activation_160[0][0]
# __________________________________________________________________________________________________
# dropout_159 (Dropout)           (None, 32, 32, 6)    0           conv2d_161[0][0]
# __________________________________________________________________________________________________
# concatenate_156 (Concatenate)   (None, 32, 32, 228)  0           concatenate_155[0][0]
#                                                                  dropout_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 32, 32, 228)  912         concatenate_156[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 32, 32, 228)  0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 32, 32, 6)    1368        activation_161[0][0]
# __________________________________________________________________________________________________
# dropout_160 (Dropout)           (None, 32, 32, 6)    0           conv2d_162[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 16, 6)    0           dropout_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 16, 16, 6)    24          average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 16, 16, 6)    0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 16, 16, 6)    324         activation_162[0][0]
# __________________________________________________________________________________________________
# dropout_161 (Dropout)           (None, 16, 16, 6)    0           conv2d_163[0][0]
# __________________________________________________________________________________________________
# concatenate_157 (Concatenate)   (None, 16, 16, 12)   0           average_pooling2d_5[0][0]
#                                                                  dropout_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 16, 16, 12)   48          concatenate_157[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 16, 16, 12)   0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 16, 16, 6)    648         activation_163[0][0]
# __________________________________________________________________________________________________
# dropout_162 (Dropout)           (None, 16, 16, 6)    0           conv2d_164[0][0]
# __________________________________________________________________________________________________
# concatenate_158 (Concatenate)   (None, 16, 16, 18)   0           concatenate_157[0][0]
#                                                                  dropout_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 16, 16, 18)   72          concatenate_158[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 16, 16, 18)   0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 16, 16, 6)    972         activation_164[0][0]
# __________________________________________________________________________________________________
# dropout_163 (Dropout)           (None, 16, 16, 6)    0           conv2d_165[0][0]
# __________________________________________________________________________________________________
# concatenate_159 (Concatenate)   (None, 16, 16, 24)   0           concatenate_158[0][0]
#                                                                  dropout_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 16, 16, 24)   96          concatenate_159[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 16, 16, 24)   0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 16, 16, 6)    1296        activation_165[0][0]
# __________________________________________________________________________________________________
# dropout_164 (Dropout)           (None, 16, 16, 6)    0           conv2d_166[0][0]
# __________________________________________________________________________________________________
# concatenate_160 (Concatenate)   (None, 16, 16, 30)   0           concatenate_159[0][0]
#                                                                  dropout_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 16, 16, 30)   120         concatenate_160[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 16, 16, 30)   0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 16, 16, 6)    1620        activation_166[0][0]
# __________________________________________________________________________________________________
# dropout_165 (Dropout)           (None, 16, 16, 6)    0           conv2d_167[0][0]
# __________________________________________________________________________________________________
# concatenate_161 (Concatenate)   (None, 16, 16, 36)   0           concatenate_160[0][0]
#                                                                  dropout_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 16, 16, 36)   144         concatenate_161[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 16, 16, 36)   0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 16, 16, 6)    1944        activation_167[0][0]
# __________________________________________________________________________________________________
# dropout_166 (Dropout)           (None, 16, 16, 6)    0           conv2d_168[0][0]
# __________________________________________________________________________________________________
# concatenate_162 (Concatenate)   (None, 16, 16, 42)   0           concatenate_161[0][0]
#                                                                  dropout_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 16, 16, 42)   168         concatenate_162[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 16, 16, 42)   0           batch_normalization_168[0][0]
# ...
# conv2d_235 (Conv2D)             (None, 8, 8, 6)      11664       activation_234[0][0]
# __________________________________________________________________________________________________
# dropout_233 (Dropout)           (None, 8, 8, 6)      0           conv2d_235[0][0]
# __________________________________________________________________________________________________
# concatenate_228 (Concatenate)   (None, 8, 8, 222)    0           concatenate_227[0][0]
#                                                                  dropout_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 8, 8, 222)    888         concatenate_228[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 8, 8, 222)    0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 8, 8, 6)      1332        activation_235[0][0]
# __________________________________________________________________________________________________
# dropout_234 (Dropout)           (None, 8, 8, 6)      0           conv2d_236[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 4, 4, 6)      0           dropout_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 4, 4, 6)      24          average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 4, 4, 6)      0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 4, 4, 6)      324         activation_236[0][0]
# __________________________________________________________________________________________________
# dropout_235 (Dropout)           (None, 4, 4, 6)      0           conv2d_237[0][0]
# __________________________________________________________________________________________________
# concatenate_229 (Concatenate)   (None, 4, 4, 12)     0           average_pooling2d_7[0][0]
#                                                                  dropout_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 4, 4, 12)     48          concatenate_229[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 4, 4, 12)     0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 4, 4, 6)      648         activation_237[0][0]
# __________________________________________________________________________________________________
# dropout_236 (Dropout)           (None, 4, 4, 6)      0           conv2d_238[0][0]
# __________________________________________________________________________________________________
# concatenate_230 (Concatenate)   (None, 4, 4, 18)     0           concatenate_229[0][0]
#                                                                  dropout_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 4, 4, 18)     72          concatenate_230[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 4, 4, 18)     0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 4, 4, 6)      972         activation_238[0][0]
# __________________________________________________________________________________________________
# dropout_237 (Dropout)           (None, 4, 4, 6)      0           conv2d_239[0][0]
# __________________________________________________________________________________________________
# concatenate_231 (Concatenate)   (None, 4, 4, 24)     0           concatenate_230[0][0]
#                                                                  dropout_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 4, 4, 24)     96          concatenate_231[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 4, 4, 24)     0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 4, 4, 6)      1296        activation_239[0][0]
# __________________________________________________________________________________________________
# dropout_238 (Dropout)           (None, 4, 4, 6)      0           conv2d_240[0][0]
# __________________________________________________________________________________________________
# concatenate_232 (Concatenate)   (None, 4, 4, 30)     0           concatenate_231[0][0]
#                                                                  dropout_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 4, 4, 30)     120         concatenate_232[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 4, 4, 30)     0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 4, 4, 6)      1620        activation_240[0][0]
# __________________________________________________________________________________________________
# dropout_239 (Dropout)           (None, 4, 4, 6)      0           conv2d_241[0][0]
# __________________________________________________________________________________________________
# concatenate_233 (Concatenate)   (None, 4, 4, 36)     0           concatenate_232[0][0]
#                                                                  dropout_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 4, 4, 36)     144         concatenate_233[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 4, 4, 36)     0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 4, 4, 6)      1944        activation_241[0][0]
# __________________________________________________________________________________________________
# dropout_240 (Dropout)           (None, 4, 4, 6)      0           conv2d_242[0][0]
# __________________________________________________________________________________________________
# concatenate_234 (Concatenate)   (None, 4, 4, 42)     0           concatenate_233[0][0]
#                                                                  dropout_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 4, 4, 42)     168         concatenate_234[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 4, 4, 42)     0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 4, 4, 6)      2268        activation_242[0][0]
# __________________________________________________________________________________________________
# dropout_241 (Dropout)           (None, 4, 4, 6)      0           conv2d_243[0][0]
# __________________________________________________________________________________________________
# concatenate_235 (Concatenate)   (None, 4, 4, 48)     0           concatenate_234[0][0]
#                                                                  dropout_241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 4, 4, 48)     192         concatenate_235[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 4, 4, 48)     0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 4, 4, 6)      2592        activation_243[0][0]
# __________________________________________________________________________________________________
# dropout_242 (Dropout)           (None, 4, 4, 6)      0           conv2d_244[0][0]
# __________________________________________________________________________________________________
# concatenate_236 (Concatenate)   (None, 4, 4, 54)     0           concatenate_235[0][0]
#                                                                  dropout_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 4, 4, 54)     216         concatenate_236[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 4, 4, 54)     0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 4, 4, 6)      2916        activation_244[0][0]
# __________________________________________________________________________________________________
# dropout_243 (Dropout)           (None, 4, 4, 6)      0           conv2d_245[0][0]
# __________________________________________________________________________________________________
# concatenate_237 (Concatenate)   (None, 4, 4, 60)     0           concatenate_236[0][0]
#                                                                  dropout_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 4, 4, 60)     240         concatenate_237[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 4, 4, 60)     0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 4, 4, 6)      3240        activation_245[0][0]
# __________________________________________________________________________________________________
# dropout_244 (Dropout)           (None, 4, 4, 6)      0           conv2d_246[0][0]
# __________________________________________________________________________________________________
# concatenate_238 (Concatenate)   (None, 4, 4, 66)     0           concatenate_237[0][0]
#                                                                  dropout_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 4, 4, 66)     264         concatenate_238[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 4, 4, 66)     0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 4, 4, 6)      3564        activation_246[0][0]
# __________________________________________________________________________________________________
# dropout_245 (Dropout)           (None, 4, 4, 6)      0           conv2d_247[0][0]
# __________________________________________________________________________________________________
# concatenate_239 (Concatenate)   (None, 4, 4, 72)     0           concatenate_238[0][0]
#                                                                  dropout_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 4, 4, 72)     288         concatenate_239[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 4, 4, 72)     0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 4, 4, 6)      3888        activation_247[0][0]
# __________________________________________________________________________________________________
# dropout_246 (Dropout)           (None, 4, 4, 6)      0           conv2d_248[0][0]
# __________________________________________________________________________________________________
# concatenate_240 (Concatenate)   (None, 4, 4, 78)     0           concatenate_239[0][0]
#                                                                  dropout_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 4, 4, 78)     312         concatenate_240[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 4, 4, 78)     0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 2, 2, 78)     0           activation_248[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 312)          0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           3130        flatten_2[0][0]
# ==================================================================================================
# Total params: 745,462
# Trainable params: 718,618
# Non-trainable params: 26,844
# __________________________________________________________________________________________________

# %%
#train model
hl=model_large.fit(x_train, y_train, batch_size=batch_size, verbose=1,
                epochs=model_large_epochs1, callbacks=callbacks,
                validation_data=(x_test, y_test))
model_large.save(model_file)
print("Saved model to disk")
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/100
#    256/100000 [..............................] - ETA: 2:51:43 - loss: 2.2939 - acc: 0.1641
# /jet/var/python/lib/python3.6/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.472004). Check your callbacks.
#   % delta_t_median)
# 100000/100000 [==============================] - 335s 3ms/step - loss: 0.7942 - acc: 0.7230 - val_loss: 0.7969 - val_acc: 0.7651
# Epoch 2/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.7495 - acc: 0.7398 - val_loss: 1.2690 - val_acc: 0.6877
#
# Epoch 00002: val_acc improved from -inf to 0.68770, saving model to large_weights.02-0.69.h5
# Epoch 3/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.7386 - acc: 0.7428 - val_loss: 0.7269 - val_acc: 0.7748
# Epoch 4/100
# 100000/100000 [==============================] - 306s 3ms/step - loss: 0.7264 - acc: 0.7475 - val_loss: 0.8693 - val_acc: 0.7572
#
# Epoch 00004: val_acc improved from 0.68770 to 0.75720, saving model to large_weights.04-0.76.h5
# Epoch 5/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.7136 - acc: 0.7512 - val_loss: 0.6814 - val_acc: 0.7898
# Epoch 6/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.6997 - acc: 0.7562 - val_loss: 1.0623 - val_acc: 0.7172
#
# Epoch 00006: val_acc did not improve from 0.75720
# Epoch 7/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.6919 - acc: 0.7596 - val_loss: 0.7962 - val_acc: 0.7721
# Epoch 8/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.6760 - acc: 0.7645 - val_loss: 1.0556 - val_acc: 0.7193
#
# Epoch 00008: val_acc did not improve from 0.75720
# Epoch 9/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.6604 - acc: 0.7705 - val_loss: 0.7759 - val_acc: 0.7898
# Epoch 10/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.6369 - acc: 0.7783 - val_loss: 0.9414 - val_acc: 0.7579
#
# Epoch 00010: val_acc improved from 0.75720 to 0.75790, saving model to large_weights.10-0.76.h5
# Epoch 11/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.6186 - acc: 0.7854 - val_loss: 0.9598 - val_acc: 0.7422
# Epoch 12/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.6017 - acc: 0.7904 - val_loss: 0.9127 - val_acc: 0.7616
#
# Epoch 00012: val_acc improved from 0.75790 to 0.76160, saving model to large_weights.12-0.76.h5
# Epoch 13/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.5835 - acc: 0.7971 - val_loss: 0.6826 - val_acc: 0.8017
# Epoch 14/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.5668 - acc: 0.8024 - val_loss: 0.7717 - val_acc: 0.7937
#
# Epoch 00014: val_acc improved from 0.76160 to 0.79370, saving model to large_weights.14-0.79.h5
# Epoch 15/100
# 100000/100000 [==============================] - 306s 3ms/step - loss: 0.5535 - acc: 0.8067 - val_loss: 0.6677 - val_acc: 0.8095
# Epoch 16/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.5399 - acc: 0.8123 - val_loss: 0.8379 - val_acc: 0.7876
#
# Epoch 00016: val_acc did not improve from 0.79370
# Epoch 17/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.5337 - acc: 0.8131 - val_loss: 0.7822 - val_acc: 0.8009
# Epoch 18/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5321 - acc: 0.8145 - val_loss: 0.5865 - val_acc: 0.8291
#
# Epoch 00018: val_acc improved from 0.79370 to 0.82910, saving model to large_weights.18-0.83.h5
# Epoch 19/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5325 - acc: 0.8152 - val_loss: 0.6458 - val_acc: 0.8196
# Epoch 20/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5264 - acc: 0.8167 - val_loss: 0.6815 - val_acc: 0.8183
#
# Epoch 00020: val_acc did not improve from 0.82910
# Epoch 21/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5241 - acc: 0.8168 - val_loss: 0.6545 - val_acc: 0.8189
# Epoch 22/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5274 - acc: 0.8174 - val_loss: 0.7913 - val_acc: 0.7829
#
# Epoch 00022: val_acc did not improve from 0.82910
# Epoch 23/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5220 - acc: 0.8183 - val_loss: 0.7001 - val_acc: 0.8117
# Epoch 24/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5182 - acc: 0.8200 - val_loss: 0.6831 - val_acc: 0.8201
#
# Epoch 00024: val_acc did not improve from 0.82910
# Epoch 25/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5135 - acc: 0.8205 - val_loss: 1.4607 - val_acc: 0.7027
# Epoch 26/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.5025 - acc: 0.8244 - val_loss: 0.7940 - val_acc: 0.7957
#
# Epoch 00026: val_acc did not improve from 0.82910
# Epoch 27/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4941 - acc: 0.8279 - val_loss: 0.7751 - val_acc: 0.8072
# Epoch 28/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4864 - acc: 0.8297 - val_loss: 0.7107 - val_acc: 0.8069
#
# Epoch 00028: val_acc did not improve from 0.82910
# Epoch 29/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4789 - acc: 0.8318 - val_loss: 0.6906 - val_acc: 0.8151
# Epoch 30/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4701 - acc: 0.8360 - val_loss: 0.7939 - val_acc: 0.7939
#
# Epoch 00030: val_acc did not improve from 0.82910
# Epoch 31/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4638 - acc: 0.8372 - val_loss: 0.5428 - val_acc: 0.8490
# Epoch 32/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4533 - acc: 0.8420 - val_loss: 0.6324 - val_acc: 0.8398
#
# Epoch 00032: val_acc improved from 0.82910 to 0.83980, saving model to large_weights.32-0.84.h5
# Epoch 33/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4499 - acc: 0.8424 - val_loss: 0.7040 - val_acc: 0.8222
# Epoch 34/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4511 - acc: 0.8420 - val_loss: 0.6854 - val_acc: 0.8316
#
# Epoch 00034: val_acc did not improve from 0.83980
# Epoch 35/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4479 - acc: 0.8424 - val_loss: 0.7927 - val_acc: 0.8055
# Epoch 36/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4462 - acc: 0.8436 - val_loss: 0.8444 - val_acc: 0.8020
#
# Epoch 00036: val_acc did not improve from 0.83980
# Epoch 37/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4456 - acc: 0.8430 - val_loss: 0.6711 - val_acc: 0.8184
#
# Epoch 00038: val_acc did not improve from 0.83980
# Epoch 39/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4426 - acc: 0.8457 - val_loss: 0.5747 - val_acc: 0.8385
# Epoch 40/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4419 - acc: 0.8451 - val_loss: 0.6669 - val_acc: 0.8240
#
# Epoch 00040: val_acc did not improve from 0.83980
# Epoch 41/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4356 - acc: 0.8481 - val_loss: 0.5764 - val_acc: 0.8426
# Epoch 42/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4306 - acc: 0.8496 - val_loss: 0.5724 - val_acc: 0.8494
#
# Epoch 00042: val_acc improved from 0.83980 to 0.84940, saving model to large_weights.42-0.85.h5
# Epoch 43/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4229 - acc: 0.8509 - val_loss: 0.6897 - val_acc: 0.8267
# Epoch 44/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4206 - acc: 0.8543 - val_loss: 0.6354 - val_acc: 0.8317
#
# Epoch 00044: val_acc did not improve from 0.84940
# Epoch 45/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4140 - acc: 0.8548 - val_loss: 0.8078 - val_acc: 0.8069
# Epoch 46/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4121 - acc: 0.8550 - val_loss: 0.5700 - val_acc: 0.8473
#
# Epoch 00046: val_acc did not improve from 0.84940
# Epoch 47/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4073 - acc: 0.8568 - val_loss: 0.6889 - val_acc: 0.8269
# Epoch 48/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4059 - acc: 0.8577 - val_loss: 0.8372 - val_acc: 0.8066
#
# Epoch 00048: val_acc did not improve from 0.84940
# Epoch 49/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3990 - acc: 0.8589 - val_loss: 1.0220 - val_acc: 0.7716
# Epoch 50/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4007 - acc: 0.8586 - val_loss: 0.7983 - val_acc: 0.8146
#
# Epoch 00050: val_acc did not improve from 0.84940
# Epoch 51/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4001 - acc: 0.8597 - val_loss: 0.7581 - val_acc: 0.8215
# Epoch 52/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3978 - acc: 0.8601 - val_loss: 0.7696 - val_acc: 0.8096
#
# Epoch 00052: val_acc did not improve from 0.84940
# Epoch 53/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3955 - acc: 0.8610 - val_loss: 0.6235 - val_acc: 0.8375
# Epoch 54/100
# 100000/100000 [==============================] - 306s 3ms/step - loss: 0.3947 - acc: 0.8614 - val_loss: 0.8536 - val_acc: 0.7982
#
# Epoch 00054: val_acc did not improve from 0.84940
# Epoch 55/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3928 - acc: 0.8611 - val_loss: 0.7622 - val_acc: 0.8178
# Epoch 56/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3921 - acc: 0.8617 - val_loss: 0.7113 - val_acc: 0.8271
#
# Epoch 00056: val_acc did not improve from 0.84940
# Epoch 57/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3862 - acc: 0.8638 - val_loss: 0.5852 - val_acc: 0.8494
#
# Epoch 00058: val_acc did not improve from 0.84940
# Epoch 59/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3866 - acc: 0.8633 - val_loss: 0.6091 - val_acc: 0.8453
# Epoch 60/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3789 - acc: 0.8656 - val_loss: 0.6140 - val_acc: 0.8456
#
# Epoch 00060: val_acc did not improve from 0.84940
# Epoch 61/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3779 - acc: 0.8663 - val_loss: 0.6148 - val_acc: 0.8454
# Epoch 62/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3744 - acc: 0.8670 - val_loss: 0.6982 - val_acc: 0.8347
#
# Epoch 00062: val_acc did not improve from 0.84940
# Epoch 63/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3700 - acc: 0.8699 - val_loss: 0.6199 - val_acc: 0.8423
# Epoch 64/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3671 - acc: 0.8703 - val_loss: 0.5866 - val_acc: 0.8463
#
# Epoch 00064: val_acc did not improve from 0.84940
# Epoch 65/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3654 - acc: 0.8725 - val_loss: 0.5803 - val_acc: 0.8558
# Epoch 66/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3631 - acc: 0.8718 - val_loss: 0.5879 - val_acc: 0.8577
#
# Epoch 00066: val_acc improved from 0.84940 to 0.85770, saving model to large_weights.66-0.86.h5
# Epoch 67/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3614 - acc: 0.8721 - val_loss: 0.9766 - val_acc: 0.7919
# Epoch 68/100
# 100000/100000 [==============================] - 306s 3ms/step - loss: 0.3607 - acc: 0.8732 - val_loss: 0.5858 - val_acc: 0.8484
#
# Epoch 00068: val_acc did not improve from 0.85770
# Epoch 69/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3585 - acc: 0.8733 - val_loss: 0.6373 - val_acc: 0.8352
#
# Epoch 00070: val_acc did not improve from 0.85770
# Epoch 71/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3412 - acc: 0.8796 - val_loss: 0.7545 - val_acc: 0.8334
# Epoch 80/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3408 - acc: 0.8792 - val_loss: 0.7699 - val_acc: 0.8191
#
# Epoch 00080: val_acc did not improve from 0.85770
# Epoch 81/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3427 - acc: 0.8796 - val_loss: 0.6117 - val_acc: 0.8507
# Epoch 82/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3379 - acc: 0.8803 - val_loss: 0.6842 - val_acc: 0.8390
#
# Epoch 00082: val_acc did not improve from 0.85770
# Epoch 83/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3385 - acc: 0.8807 - val_loss: 0.5556 - val_acc: 0.8602
# Epoch 84/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3349 - acc: 0.8813 - val_loss: 0.6332 - val_acc: 0.8482
#
# Epoch 00084: val_acc did not improve from 0.85770
# Epoch 85/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3350 - acc: 0.8818 - val_loss: 0.5547 - val_acc: 0.8559
# Epoch 86/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3354 - acc: 0.8809 - val_loss: 0.7001 - val_acc: 0.8346
#
# Epoch 00086: val_acc did not improve from 0.85770
# Epoch 87/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3347 - acc: 0.8819 - val_loss: 0.6546 - val_acc: 0.8426
# Epoch 88/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3301 - acc: 0.8830 - val_loss: 0.7005 - val_acc: 0.8375
#
# Epoch 00088: val_acc did not improve from 0.85770
# Epoch 89/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3323 - acc: 0.8825 - val_loss: 0.6923 - val_acc: 0.8378
# Epoch 90/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3298 - acc: 0.8830 - val_loss: 0.6691 - val_acc: 0.8344
#
# Epoch 00090: val_acc did not improve from 0.85770
# Epoch 91/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3249 - acc: 0.8848 - val_loss: 0.7563 - val_acc: 0.8269
# Epoch 92/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3268 - acc: 0.8852 - val_loss: 0.6523 - val_acc: 0.8457
#
# Epoch 00092: val_acc did not improve from 0.85770
# Epoch 93/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3208 - acc: 0.8858 - val_loss: 0.9000 - val_acc: 0.8059
# Epoch 94/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3226 - acc: 0.8855 - val_loss: 0.7221 - val_acc: 0.8282
#
# Epoch 00094: val_acc did not improve from 0.85770
# Epoch 95/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3221 - acc: 0.8853 - val_loss: 0.6914 - val_acc: 0.8398
# Epoch 96/100
# 100000/100000 [==============================] - 306s 3ms/step - loss: 0.3203 - acc: 0.8870 - val_loss: 0.7341 - val_acc: 0.8334
#
# Epoch 00096: val_acc did not improve from 0.85770
# Epoch 97/100
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3202 - acc: 0.8858 - val_loss: 0.5412 - val_acc: 0.8526
# Epoch 98/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3160 - acc: 0.8868 - val_loss: 0.5985 - val_acc: 0.8533
#
# Epoch 00098: val_acc did not improve from 0.85770
# Epoch 99/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3148 - acc: 0.8890 - val_loss: 0.7093 - val_acc: 0.8425
# Epoch 100/100
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3129 - acc: 0.8890 - val_loss: 0.6450 - val_acc: 0.8516
#
# Epoch 00100: val_acc did not improve from 0.85770
# Saved model to disk

# %%
#callbacks
model_checkpointer=ModelCheckpoint('large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.001, max_lr=0.3,step_size=6*(len(y_train)/batch_size),mode='triangular2',gamma=0.99994)
#aggresively decrease lr

# M = 6
# nb_epoch = T = 200
# alpha_zero = 0.1
# model_prefix = 'ensemble_'
# snapshot = SnapshotCallbackBuilder(T, M, alpha_zero) 


# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
callbacks = [clr, model_checkpointer]

# %%
#train model
hl2=model_large.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_large_epochs1,
                epochs=model_large_epochs1+model_large_epochs2, callbacks=callbacks,
                validation_data=(x_test, y_test))
model_large.save(model_file)
print("Saved model to disk")
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 101/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2840 - acc: 0.8995 - val_loss: 0.5287 - val_acc: 0.8737
# Epoch 102/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.4409 - acc: 0.8451 - val_loss: 0.7961 - val_acc: 0.7946
# Epoch 108/180
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.4043 - acc: 0.8576 - val_loss: 0.5934 - val_acc: 0.8436
#
# Epoch 00108: val_acc did not improve from 0.85590
# Epoch 109/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3714 - acc: 0.8704 - val_loss: 0.5806 - val_acc: 0.8471
# Epoch 110/180
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.3344 - acc: 0.8822 - val_loss: 0.5118 - val_acc: 0.8637
#
# Epoch 00110: val_acc improved from 0.85590 to 0.86370, saving model to large_weights.110-0.86.h5
# Epoch 111/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2959 - acc: 0.8943 - val_loss: 0.5830 - val_acc: 0.8648
# Epoch 112/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2649 - acc: 0.9056 - val_loss: 0.5616 - val_acc: 0.8690
#
# Epoch 00112: val_acc improved from 0.86370 to 0.86900, saving model to large_weights.112-0.87.h5
# Epoch 113/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2466 - acc: 0.9113 - val_loss: 0.6144 - val_acc: 0.8621
# Epoch 114/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2569 - acc: 0.9089 - val_loss: 0.6266 - val_acc: 0.8583
#
# Epoch 00114: val_acc did not improve from 0.86900
# Epoch 115/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.2683 - acc: 0.9044 - val_loss: 0.5690 - val_acc: 0.8686
# Epoch 116/180
# 100000/100000 [==============================] - 304s 3ms/step - loss: 0.2860 - acc: 0.8985 - val_loss: 0.6237 - val_acc: 0.8545
#
# Epoch 00116: val_acc did not improve from 0.86900
# Epoch 117/180
# 100000/100000 [==============================] - 305s 3ms/step - loss: 0.3024 - acc: 0.8922 - val_loss: 0.6659 - val_acc: 0.8426
# Epoch 118/180
#   9344/100000 [=>............................] - ETA: 4:27 - loss: 0.3190 - acc: 0.8859
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1532a1e2b8b7> in <module>()
#       2 hl2=model_large.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_large_epochs1,
#       3                 epochs=model_large_epochs1+model_large_epochs2, callbacks=callbacks,
# ----> 4                 validation_data=(x_test, y_test))
#       5 model_large.save(model_file)
#       6 print("Saved model to disk")
#
# /jet/var/python/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# /jet/var/python/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /jet/var/python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# /jet/var/python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# /jet/var/python/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model_checkpointer=ModelCheckpoint('large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
clr = CyclicLR(base_lr=0.001, max_lr=0.1,step_size=6*(len(y_train)/batch_size),mode='triangular')
#start increasing lr since model has begun to overfit
callbacks = [clr, model_checkpointer]
model_large_2=load_model('large_weights.112-0.87.h5')

# %%
#train model
hl3=model_large_2.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=117,
                epochs=model_large_epochs1+model_large_epochs2, callbacks=callbacks,
                validation_data=(x_test, y_test))
model_large.save(model_file)
print("Saved model to disk")
# Out:
# Train on 100000 samples, validate on 10000 samples
# Epoch 118/180
# 100000/100000 [==============================] - 333s 3ms/step - loss: 0.2445 - acc: 0.9124 - val_loss: 0.5846 - val_acc: 0.8674
# Epoch 119/180
#   7296/100000 [=>............................] - ETA: 4:32 - loss: 0.2398 - acc: 0.9184

# %%
# Test the model
score = model_large.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
print('====================END OF LARGER MODEL====================')

# %%
score = model_large.evaluate(x_test, y_test, verbose=1)
s=open('res.txt','w')
s.write(score[0],score[1])
s.close()

# %%
s=open('res.txt','a')
s.write(str(hl))
s.close()
