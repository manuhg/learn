# %%
# !pip install -q six numpy scipy matplotlib scikit-image opencv-python imageio
# !pip install -q keras imgaug
# !pip install -q keras

# %%
import keras
from imgaug import augmenters as ia
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import SGD
from keras.callbacks import *
from keras.models import load_model


# from keras.callbacks import LearningRateScheduler,ModelCheckpoint,EarlyStopping,LambdaCallback
import os,sys,math

# %%
import google
colab_dir='./'
file_name='EIP_CIFAR_10'
if hasattr(google,'colab'):
    from google.colab import drive
    drive.mount('/content/gdrive')
    colab_dir='/content/gdrive/My Drive/Colab Notebooks/'
model_file=colab_dir+file_name+'.h5'

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
#Augmentation and resizing
#augment and then concat samples with original
def augment(dataset,flip=0.5,blur=1.0,crop=(0,10)):
    seq = ia.Sequential([ia.Fliplr(flip),ia.GaussianBlur(sigma=(0, blur)),ia.Crop(px=crop)])
    return seq.augment_images(dataset)

def augmenter(X,y,start=.25,end=.75):
    ln=len(X)
    print('Before augmentation:',X.shape,y.shape)
    start=int(start*ln)
    end=int(end*ln)
    new_X=augment(X)[start:end]
    new_y=y[start:end]
    X=np.concatenate((X,new_X))
    y=np.concatenate((y,new_y))
    print('After augmentation:',X.shape,y.shape)
    return (X,y)

#26x26 is almost half of 32x32. 22x22 maybe too small even though its exact half.
def resize_imgs(imgs,shape=(26,26)):
    seq = ia.Sequential([ia.Scale({"height": shape[0], "width": shape[1]})])
    return seq.augment_images(imgs)

# %%
# Dense Block
def add_denseblock(input, num_filter = 12, dropout_rate = 0.2,num_layers=12):
    global compression
    temp = input
    for _ in range(num_layers):
        BatchNorm = BatchNormalization()(temp)
        relu = Activation('relu')(BatchNorm)
        Conv2D_3_3 = Conv2D(int(num_filter*compression), (3,3),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
        if dropout_rate>0:
            Conv2D_3_3 = Dropout(dropout_rate)(Conv2D_3_3)
        concat = Concatenate(axis=-1)([temp,Conv2D_3_3])        
        temp = concat        
    return temp

def add_transition(input, num_filter = 12, dropout_rate = 0.2):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    Conv2D_BottleNeck = Conv2D(int(num_filter*compression), (1,1),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
    if dropout_rate>0:
        Conv2D_BottleNeck = Dropout(dropout_rate)(Conv2D_BottleNeck)
    avg = AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)    
    return avg

def output_layer(input):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    AvgPooling = AveragePooling2D(pool_size=(2,2))(relu)
    flat = Flatten()(AvgPooling)
    output = Dense(num_classes, activation='softmax')(flat)    
    return output
  
def dense_unit(input_layer,num_filter, dropout_rate,num_layers):
    dense_block=add_denseblock(input_layer, num_filter, dropout_rate,num_layers)
    transition_block=add_transition(dense_block, num_filter, dropout_rate)
    return transition_block
  
def dense_units_chain(n,input_layer,num_filter, dropout_rate,num_layers):
    dense_unit_=input_layer
    for i in range(n):
        dense_unit_=dense_unit(dense_unit_,num_filter, dropout_rate,num_layers)
    return dense_unit_

# %%
#callback classes
#try building model with clr, snapshot ensemble

class CyclicLR(Callback):
    "source: https://github.com/bckenstler/CLR/blob/master/clr_callback.py"
    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())
        
###################################################################################################
###################################################################################################
class SnapshotModelCheckpoint(Callback):
    """source : https://github.com/titu1994/Snapshot-Ensembles/blob/master/snapshot.py"""
    def __init__(self, nb_epochs, nb_snapshots, fn_prefix='Model'):
        super(SnapshotModelCheckpoint, self).__init__()

        self.check = nb_epochs // nb_snapshots
        self.fn_prefix = fn_prefix

    def on_epoch_end(self, epoch, logs={}):
        if epoch != 0 and (epoch + 1) % self.check == 0:
            filepath = self.fn_prefix + "-%d.h5" % ((epoch + 1) // self.check)
            self.model.save_weights(filepath, overwrite=True)
            #print("Saved snapshot at weights/%s_%d.h5" % (self.fn_prefix, epoch))


class SnapshotCallbackBuilder:
    def __init__(self, nb_epochs, nb_snapshots, init_lr=0.1):
        self.T = nb_epochs
        self.M = nb_snapshots
        self.alpha_zero = init_lr

    def get_callbacks(self, model_prefix='Model'):
        """
        Creates a list of callbacks that can be used during training to create a
        snapshot ensemble of the model.
        Args:
            model_prefix: prefix for the filename of the weights.
        Returns: list of 3 callbacks [ModelCheckpoint, LearningRateScheduler,
                 SnapshotModelCheckpoint] which can be provided to the 'fit' function
        """
        if not os.path.exists('weights/'):
            os.makedirs('weights/')

        callback_list = [callbacks.ModelCheckpoint("weights/%s-Best.h5" % model_prefix, monitor="val_acc",
                                                    save_best_only=True, save_weights_only=True),
                         callbacks.LearningRateScheduler(schedule=self._cosine_anneal_schedule),
                         SnapshotModelCheckpoint(self.T, self.M, fn_prefix='weights/%s' % model_prefix)]

        return callback_list

    def _cosine_anneal_schedule(self, t):
        cos_inner = np.pi * (t % (self.T // self.M))  # t - 1 is used when t has 1-based indexing.
        cos_inner /= self.T // self.M
        cos_out = np.cos(cos_inner) + 1
        return float(self.alpha_zero / 2 * cos_out)

# %%
def load_prev_model(model_small=None):
#     print(os.popen('du -sh '+colab_dir+'*').read())
    last_best=os.popen('du -sh '+colab_dir+r'*|sed -r "s/^[0-9\.]+[MK]?\s(.*)$/\1/g;"|tail -1').read().strip()
    model_prev=None
    try:
        print('Attempting to load last best model from file - ',end='')
        last_best_fn=last_best.split('/')[-1]
        last_best_epoch=last_best_fn.split('.')[1].split('-')[0]
        model_prev=load_model(last_best)
        print('Sucess\nLoaded '+last_best_fn, 'epoch :', last_best_epoch)
    except Exception as e:
        print('Failed!\n',e)
        try:
            print('Attempting to load last saved model from file - ',end='')
            model_prev = load_model(model_file)
            print('Sucess\nLoaded model from file',model_file)
        except Exception as e:
    #         print(str(e), 'at line ', sys.exc_info()[2].tb_lineno)
            print('Failed!\n',e)
            try:
                print('Attempting to load in memory, small model - ',end='')
                if len(model_small.layers)>1:
                    model_prev=model_small
                print('Sucess')
            except Exception as e:
                print('Failed!\n',e)
    return model_prev

# %%
#new model with larger i/p layer
def larger_model(src_model,shape=(32,32,3)):
    new_input=Input(shape)
    src_model.layers.pop(0)
    new_output=src_model(new_input)
    new_model=Model(new_input,new_output)
    return new_model

# Load CIFAR10 Data
def load_data(resize=False,shape=(26,26),test_augment=False):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    
    if resize:
        x_train=resize_imgs(x_train,shape)
        x_test=resize_imgs(x_test,shape)
    
    (x_train, y_train) = augmenter(x_train, y_train,end=1)
    if test_augment:
        (x_test, y_test) = augmenter(x_test, y_test,end=1)
    return (x_train, y_train,x_test, y_test)
#create a dnn model
def create_model(input_shape,num_layers,input=None):
    print('Creating model with input shape',input_shape)
    if input is None:
        input = Input(input_shape)
    First_Conv2D = Conv2D(num_filter, (3,3), use_bias=False ,padding='same')(input)
    hidden_dense_blocks = dense_units_chain(n_dense_blocks,First_Conv2D,num_filter,dropout_rate,num_layers)
    Last_Block = add_denseblock(hidden_dense_blocks, num_filter, dropout_rate)
    output = output_layer(Last_Block)
    model = Model(inputs=[input], outputs=[output])
    return model

# %%
print('====================HYPER PARAMETERS====================')
# Out:
# ====================HYPER PARAMETERS====================

# %%
# Hyperparameters
batch_size = 128
num_classes = 10
max_epochs = 250
model_small_epochs=1
model_large_epochs1=170
# model_large_epochs2=60

num_layers = 40
# layers_small=12
# layers_large=num_layers-layers_small
layers_large=layers_small=num_layers
num_filter = 12
compression = 0.5
dropout_rate = 0.2
n_dense_blocks = 3
smaller_input=(26,26,3)

# %%
print('====================BEGIN OF SMALLER MODEL====================')
# Out:
# ====================BEGIN OF SMALLER MODEL====================

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=True,shape=smaller_input[:-1])

#callbacks
model_checkpointer=ModelCheckpoint('small_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.1, max_lr=0.2,step_size=8*(len(y_train)/batch_size))

M = 6
nb_epoch = T = 200
alpha_zero = 0.1
model_prefix = 'ensemble_'
snapshot = SnapshotCallbackBuilder(T, M, alpha_zero) 


# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
callbacks = [clr, model_checkpointer]
# Out:
# Before augmentation: (50000, 26, 26, 3) (50000, 10)
# After augmentation: (87500, 26, 26, 3) (87500, 10)

# %%
#create model
model_small = create_model((x_train.shape[1:]),num_layers=layers_small)
model_small.compile(loss='categorical_crossentropy',metrics=['accuracy'],
              optimizer=SGD(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True))
model_small.summary()
# Out:
# Creating model with input shape (26, 26, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 26, 26, 3)    0
# __________________________________________________________________________________________________
# conv2d_2612 (Conv2D)            (None, 26, 26, 12)   324         input_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2612 (Batch (None, 26, 26, 12)   48          conv2d_2612[0][0]
# __________________________________________________________________________________________________
# activation_2611 (Activation)    (None, 26, 26, 12)   0           batch_normalization_2612[0][0]
# __________________________________________________________________________________________________
# conv2d_2613 (Conv2D)            (None, 26, 26, 6)    648         activation_2611[0][0]
# __________________________________________________________________________________________________
# dropout_2599 (Dropout)          (None, 26, 26, 6)    0           conv2d_2613[0][0]
# __________________________________________________________________________________________________
# concatenate_2561 (Concatenate)  (None, 26, 26, 18)   0           conv2d_2612[0][0]
#                                                                  dropout_2599[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2613 (Batch (None, 26, 26, 18)   72          concatenate_2561[0][0]
# __________________________________________________________________________________________________
# activation_2612 (Activation)    (None, 26, 26, 18)   0           batch_normalization_2613[0][0]
# __________________________________________________________________________________________________
# conv2d_2614 (Conv2D)            (None, 26, 26, 6)    972         activation_2612[0][0]
# __________________________________________________________________________________________________
# dropout_2600 (Dropout)          (None, 26, 26, 6)    0           conv2d_2614[0][0]
# __________________________________________________________________________________________________
# concatenate_2562 (Concatenate)  (None, 26, 26, 24)   0           concatenate_2561[0][0]
#                                                                  dropout_2600[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2614 (Batch (None, 26, 26, 24)   96          concatenate_2562[0][0]
# __________________________________________________________________________________________________
# activation_2613 (Activation)    (None, 26, 26, 24)   0           batch_normalization_2614[0][0]
# __________________________________________________________________________________________________
# conv2d_2615 (Conv2D)            (None, 26, 26, 6)    1296        activation_2613[0][0]
# __________________________________________________________________________________________________
# dropout_2601 (Dropout)          (None, 26, 26, 6)    0           conv2d_2615[0][0]
# __________________________________________________________________________________________________
# concatenate_2563 (Concatenate)  (None, 26, 26, 30)   0           concatenate_2562[0][0]
#                                                                  dropout_2601[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2615 (Batch (None, 26, 26, 30)   120         concatenate_2563[0][0]
# __________________________________________________________________________________________________
# activation_2614 (Activation)    (None, 26, 26, 30)   0           batch_normalization_2615[0][0]
# __________________________________________________________________________________________________
# conv2d_2616 (Conv2D)            (None, 26, 26, 6)    1620        activation_2614[0][0]
# __________________________________________________________________________________________________
# dropout_2602 (Dropout)          (None, 26, 26, 6)    0           conv2d_2616[0][0]
# __________________________________________________________________________________________________
# concatenate_2564 (Concatenate)  (None, 26, 26, 36)   0           concatenate_2563[0][0]
#                                                                  dropout_2602[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2616 (Batch (None, 26, 26, 36)   144         concatenate_2564[0][0]
# __________________________________________________________________________________________________
# activation_2615 (Activation)    (None, 26, 26, 36)   0           batch_normalization_2616[0][0]
# __________________________________________________________________________________________________
# conv2d_2617 (Conv2D)            (None, 26, 26, 6)    1944        activation_2615[0][0]
# __________________________________________________________________________________________________
# dropout_2603 (Dropout)          (None, 26, 26, 6)    0           conv2d_2617[0][0]
# __________________________________________________________________________________________________
# concatenate_2565 (Concatenate)  (None, 26, 26, 42)   0           concatenate_2564[0][0]
#                                                                  dropout_2603[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2617 (Batch (None, 26, 26, 42)   168         concatenate_2565[0][0]
# __________________________________________________________________________________________________
# activation_2616 (Activation)    (None, 26, 26, 42)   0           batch_normalization_2617[0][0]
# __________________________________________________________________________________________________
# conv2d_2618 (Conv2D)            (None, 26, 26, 6)    2268        activation_2616[0][0]
# __________________________________________________________________________________________________
# dropout_2604 (Dropout)          (None, 26, 26, 6)    0           conv2d_2618[0][0]
# __________________________________________________________________________________________________
# concatenate_2566 (Concatenate)  (None, 26, 26, 48)   0           concatenate_2565[0][0]
#                                                                  dropout_2604[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2618 (Batch (None, 26, 26, 48)   192         concatenate_2566[0][0]
# __________________________________________________________________________________________________
# activation_2617 (Activation)    (None, 26, 26, 48)   0           batch_normalization_2618[0][0]
# __________________________________________________________________________________________________
# conv2d_2619 (Conv2D)            (None, 26, 26, 6)    2592        activation_2617[0][0]
# __________________________________________________________________________________________________
# dropout_2605 (Dropout)          (None, 26, 26, 6)    0           conv2d_2619[0][0]
# __________________________________________________________________________________________________
# concatenate_2567 (Concatenate)  (None, 26, 26, 54)   0           concatenate_2566[0][0]
#                                                                  dropout_2605[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2619 (Batch (None, 26, 26, 54)   216         concatenate_2567[0][0]
# __________________________________________________________________________________________________
# activation_2618 (Activation)    (None, 26, 26, 54)   0           batch_normalization_2619[0][0]
# __________________________________________________________________________________________________
# conv2d_2620 (Conv2D)            (None, 26, 26, 6)    2916        activation_2618[0][0]
# __________________________________________________________________________________________________
# dropout_2606 (Dropout)          (None, 26, 26, 6)    0           conv2d_2620[0][0]
# __________________________________________________________________________________________________
# concatenate_2568 (Concatenate)  (None, 26, 26, 60)   0           concatenate_2567[0][0]
#                                                                  dropout_2606[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2620 (Batch (None, 26, 26, 60)   240         concatenate_2568[0][0]
# __________________________________________________________________________________________________
# activation_2619 (Activation)    (None, 26, 26, 60)   0           batch_normalization_2620[0][0]
# __________________________________________________________________________________________________
# conv2d_2621 (Conv2D)            (None, 26, 26, 6)    3240        activation_2619[0][0]
# __________________________________________________________________________________________________
# dropout_2607 (Dropout)          (None, 26, 26, 6)    0           conv2d_2621[0][0]
# __________________________________________________________________________________________________
# concatenate_2569 (Concatenate)  (None, 26, 26, 66)   0           concatenate_2568[0][0]
#                                                                  dropout_2607[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2621 (Batch (None, 26, 26, 66)   264         concatenate_2569[0][0]
# __________________________________________________________________________________________________
# activation_2620 (Activation)    (None, 26, 26, 66)   0           batch_normalization_2621[0][0]
# __________________________________________________________________________________________________
# conv2d_2622 (Conv2D)            (None, 26, 26, 6)    3564        activation_2620[0][0]
# __________________________________________________________________________________________________
# dropout_2608 (Dropout)          (None, 26, 26, 6)    0           conv2d_2622[0][0]
# __________________________________________________________________________________________________
# concatenate_2570 (Concatenate)  (None, 26, 26, 72)   0           concatenate_2569[0][0]
#                                                                  dropout_2608[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2622 (Batch (None, 26, 26, 72)   288         concatenate_2570[0][0]
# __________________________________________________________________________________________________
# activation_2621 (Activation)    (None, 26, 26, 72)   0           batch_normalization_2622[0][0]
# __________________________________________________________________________________________________
# conv2d_2623 (Conv2D)            (None, 26, 26, 6)    3888        activation_2621[0][0]
# __________________________________________________________________________________________________
# dropout_2609 (Dropout)          (None, 26, 26, 6)    0           conv2d_2623[0][0]
# __________________________________________________________________________________________________
# concatenate_2571 (Concatenate)  (None, 26, 26, 78)   0           concatenate_2570[0][0]
#                                                                  dropout_2609[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2623 (Batch (None, 26, 26, 78)   312         concatenate_2571[0][0]
# __________________________________________________________________________________________________
# activation_2622 (Activation)    (None, 26, 26, 78)   0           batch_normalization_2623[0][0]
# __________________________________________________________________________________________________
# conv2d_2624 (Conv2D)            (None, 26, 26, 6)    4212        activation_2622[0][0]
# __________________________________________________________________________________________________
# dropout_2610 (Dropout)          (None, 26, 26, 6)    0           conv2d_2624[0][0]
# __________________________________________________________________________________________________
# concatenate_2572 (Concatenate)  (None, 26, 26, 84)   0           concatenate_2571[0][0]
#                                                                  dropout_2610[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2624 (Batch (None, 26, 26, 84)   336         concatenate_2572[0][0]
# __________________________________________________________________________________________________
# activation_2623 (Activation)    (None, 26, 26, 84)   0           batch_normalization_2624[0][0]
# __________________________________________________________________________________________________
# conv2d_2625 (Conv2D)            (None, 26, 26, 6)    4536        activation_2623[0][0]
# __________________________________________________________________________________________________
# dropout_2611 (Dropout)          (None, 26, 26, 6)    0           conv2d_2625[0][0]
# __________________________________________________________________________________________________
# concatenate_2573 (Concatenate)  (None, 26, 26, 90)   0           concatenate_2572[0][0]
#                                                                  dropout_2611[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2625 (Batch (None, 26, 26, 90)   360         concatenate_2573[0][0]
# __________________________________________________________________________________________________
# activation_2624 (Activation)    (None, 26, 26, 90)   0           batch_normalization_2625[0][0]
# __________________________________________________________________________________________________
# conv2d_2626 (Conv2D)            (None, 26, 26, 6)    4860        activation_2624[0][0]
# __________________________________________________________________________________________________
# dropout_2612 (Dropout)          (None, 26, 26, 6)    0           conv2d_2626[0][0]
# __________________________________________________________________________________________________
# concatenate_2574 (Concatenate)  (None, 26, 26, 96)   0           concatenate_2573[0][0]
#                                                                  dropout_2612[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2626 (Batch (None, 26, 26, 96)   384         concatenate_2574[0][0]
# __________________________________________________________________________________________________
# activation_2625 (Activation)    (None, 26, 26, 96)   0           batch_normalization_2626[0][0]
# __________________________________________________________________________________________________
# conv2d_2627 (Conv2D)            (None, 26, 26, 6)    5184        activation_2625[0][0]
# __________________________________________________________________________________________________
# dropout_2613 (Dropout)          (None, 26, 26, 6)    0           conv2d_2627[0][0]
# __________________________________________________________________________________________________
# concatenate_2575 (Concatenate)  (None, 26, 26, 102)  0           concatenate_2574[0][0]
#                                                                  dropout_2613[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2627 (Batch (None, 26, 26, 102)  408         concatenate_2575[0][0]
# __________________________________________________________________________________________________
# activation_2626 (Activation)    (None, 26, 26, 102)  0           batch_normalization_2627[0][0]
# __________________________________________________________________________________________________
# conv2d_2628 (Conv2D)            (None, 26, 26, 6)    5508        activation_2626[0][0]
# __________________________________________________________________________________________________
# dropout_2614 (Dropout)          (None, 26, 26, 6)    0           conv2d_2628[0][0]
# __________________________________________________________________________________________________
# concatenate_2576 (Concatenate)  (None, 26, 26, 108)  0           concatenate_2575[0][0]
#                                                                  dropout_2614[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2628 (Batch (None, 26, 26, 108)  432         concatenate_2576[0][0]
# __________________________________________________________________________________________________
# activation_2627 (Activation)    (None, 26, 26, 108)  0           batch_normalization_2628[0][0]
# __________________________________________________________________________________________________
# conv2d_2629 (Conv2D)            (None, 26, 26, 6)    5832        activation_2627[0][0]
# __________________________________________________________________________________________________
# dropout_2615 (Dropout)          (None, 26, 26, 6)    0           conv2d_2629[0][0]
# __________________________________________________________________________________________________
# concatenate_2577 (Concatenate)  (None, 26, 26, 114)  0           concatenate_2576[0][0]
#                                                                  dropout_2615[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2629 (Batch (None, 26, 26, 114)  456         concatenate_2577[0][0]
# __________________________________________________________________________________________________
# activation_2628 (Activation)    (None, 26, 26, 114)  0           batch_normalization_2629[0][0]
# __________________________________________________________________________________________________
# conv2d_2630 (Conv2D)            (None, 26, 26, 6)    6156        activation_2628[0][0]
# __________________________________________________________________________________________________
# dropout_2616 (Dropout)          (None, 26, 26, 6)    0           conv2d_2630[0][0]
# __________________________________________________________________________________________________
# concatenate_2578 (Concatenate)  (None, 26, 26, 120)  0           concatenate_2577[0][0]
#                                                                  dropout_2616[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2630 (Batch (None, 26, 26, 120)  480         concatenate_2578[0][0]
# __________________________________________________________________________________________________
# activation_2629 (Activation)    (None, 26, 26, 120)  0           batch_normalization_2630[0][0]
# __________________________________________________________________________________________________
# conv2d_2631 (Conv2D)            (None, 26, 26, 6)    6480        activation_2629[0][0]
# __________________________________________________________________________________________________
# dropout_2617 (Dropout)          (None, 26, 26, 6)    0           conv2d_2631[0][0]
# __________________________________________________________________________________________________
# concatenate_2579 (Concatenate)  (None, 26, 26, 126)  0           concatenate_2578[0][0]
#                                                                  dropout_2617[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2631 (Batch (None, 26, 26, 126)  504         concatenate_2579[0][0]
# __________________________________________________________________________________________________
# activation_2630 (Activation)    (None, 26, 26, 126)  0           batch_normalization_2631[0][0]
# __________________________________________________________________________________________________
# conv2d_2632 (Conv2D)            (None, 26, 26, 6)    6804        activation_2630[0][0]
# __________________________________________________________________________________________________
# dropout_2618 (Dropout)          (None, 26, 26, 6)    0           conv2d_2632[0][0]
# __________________________________________________________________________________________________
# concatenate_2580 (Concatenate)  (None, 26, 26, 132)  0           concatenate_2579[0][0]
#                                                                  dropout_2618[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2632 (Batch (None, 26, 26, 132)  528         concatenate_2580[0][0]
# __________________________________________________________________________________________________
# activation_2631 (Activation)    (None, 26, 26, 132)  0           batch_normalization_2632[0][0]
# __________________________________________________________________________________________________
# conv2d_2633 (Conv2D)            (None, 26, 26, 6)    7128        activation_2631[0][0]
# __________________________________________________________________________________________________
# dropout_2619 (Dropout)          (None, 26, 26, 6)    0           conv2d_2633[0][0]
# __________________________________________________________________________________________________
# concatenate_2581 (Concatenate)  (None, 26, 26, 138)  0           concatenate_2580[0][0]
#                                                                  dropout_2619[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2633 (Batch (None, 26, 26, 138)  552         concatenate_2581[0][0]
# __________________________________________________________________________________________________
# activation_2632 (Activation)    (None, 26, 26, 138)  0           batch_normalization_2633[0][0]
# __________________________________________________________________________________________________
# conv2d_2634 (Conv2D)            (None, 26, 26, 6)    7452        activation_2632[0][0]
# __________________________________________________________________________________________________
# dropout_2620 (Dropout)          (None, 26, 26, 6)    0           conv2d_2634[0][0]
# __________________________________________________________________________________________________
# concatenate_2582 (Concatenate)  (None, 26, 26, 144)  0           concatenate_2581[0][0]
#                                                                  dropout_2620[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2634 (Batch (None, 26, 26, 144)  576         concatenate_2582[0][0]
# __________________________________________________________________________________________________
# activation_2633 (Activation)    (None, 26, 26, 144)  0           batch_normalization_2634[0][0]
# __________________________________________________________________________________________________
# conv2d_2635 (Conv2D)            (None, 26, 26, 6)    7776        activation_2633[0][0]
# __________________________________________________________________________________________________
# dropout_2621 (Dropout)          (None, 26, 26, 6)    0           conv2d_2635[0][0]
# __________________________________________________________________________________________________
# concatenate_2583 (Concatenate)  (None, 26, 26, 150)  0           concatenate_2582[0][0]
#                                                                  dropout_2621[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2635 (Batch (None, 26, 26, 150)  600         concatenate_2583[0][0]
# __________________________________________________________________________________________________
# activation_2634 (Activation)    (None, 26, 26, 150)  0           batch_normalization_2635[0][0]
# __________________________________________________________________________________________________
# conv2d_2636 (Conv2D)            (None, 26, 26, 6)    8100        activation_2634[0][0]
# __________________________________________________________________________________________________
# dropout_2622 (Dropout)          (None, 26, 26, 6)    0           conv2d_2636[0][0]
# __________________________________________________________________________________________________
# concatenate_2584 (Concatenate)  (None, 26, 26, 156)  0           concatenate_2583[0][0]
#                                                                  dropout_2622[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2636 (Batch (None, 26, 26, 156)  624         concatenate_2584[0][0]
# __________________________________________________________________________________________________
# activation_2635 (Activation)    (None, 26, 26, 156)  0           batch_normalization_2636[0][0]
# __________________________________________________________________________________________________
# conv2d_2637 (Conv2D)            (None, 26, 26, 6)    8424        activation_2635[0][0]
# __________________________________________________________________________________________________
# dropout_2623 (Dropout)          (None, 26, 26, 6)    0           conv2d_2637[0][0]
# __________________________________________________________________________________________________
# concatenate_2585 (Concatenate)  (None, 26, 26, 162)  0           concatenate_2584[0][0]
#                                                                  dropout_2623[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2637 (Batch (None, 26, 26, 162)  648         concatenate_2585[0][0]
# __________________________________________________________________________________________________
# activation_2636 (Activation)    (None, 26, 26, 162)  0           batch_normalization_2637[0][0]
# __________________________________________________________________________________________________
# conv2d_2638 (Conv2D)            (None, 26, 26, 6)    8748        activation_2636[0][0]
# __________________________________________________________________________________________________
# dropout_2624 (Dropout)          (None, 26, 26, 6)    0           conv2d_2638[0][0]
# __________________________________________________________________________________________________
# concatenate_2586 (Concatenate)  (None, 26, 26, 168)  0           concatenate_2585[0][0]
#                                                                  dropout_2624[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2638 (Batch (None, 26, 26, 168)  672         concatenate_2586[0][0]
# __________________________________________________________________________________________________
# activation_2637 (Activation)    (None, 26, 26, 168)  0           batch_normalization_2638[0][0]
# __________________________________________________________________________________________________
# conv2d_2639 (Conv2D)            (None, 26, 26, 6)    9072        activation_2637[0][0]
# __________________________________________________________________________________________________
# dropout_2625 (Dropout)          (None, 26, 26, 6)    0           conv2d_2639[0][0]
# __________________________________________________________________________________________________
# concatenate_2587 (Concatenate)  (None, 26, 26, 174)  0           concatenate_2586[0][0]
#                                                                  dropout_2625[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2639 (Batch (None, 26, 26, 174)  696         concatenate_2587[0][0]
# __________________________________________________________________________________________________
# activation_2638 (Activation)    (None, 26, 26, 174)  0           batch_normalization_2639[0][0]
# __________________________________________________________________________________________________
# conv2d_2640 (Conv2D)            (None, 26, 26, 6)    9396        activation_2638[0][0]
# __________________________________________________________________________________________________
# dropout_2626 (Dropout)          (None, 26, 26, 6)    0           conv2d_2640[0][0]
# __________________________________________________________________________________________________
# concatenate_2588 (Concatenate)  (None, 26, 26, 180)  0           concatenate_2587[0][0]
#                                                                  dropout_2626[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2640 (Batch (None, 26, 26, 180)  720         concatenate_2588[0][0]
# __________________________________________________________________________________________________
# activation_2639 (Activation)    (None, 26, 26, 180)  0           batch_normalization_2640[0][0]
# __________________________________________________________________________________________________
# conv2d_2641 (Conv2D)            (None, 26, 26, 6)    9720        activation_2639[0][0]
# __________________________________________________________________________________________________
# dropout_2627 (Dropout)          (None, 26, 26, 6)    0           conv2d_2641[0][0]
# __________________________________________________________________________________________________
# concatenate_2589 (Concatenate)  (None, 26, 26, 186)  0           concatenate_2588[0][0]
#                                                                  dropout_2627[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2641 (Batch (None, 26, 26, 186)  744         concatenate_2589[0][0]
# __________________________________________________________________________________________________
# activation_2640 (Activation)    (None, 26, 26, 186)  0           batch_normalization_2641[0][0]
# __________________________________________________________________________________________________
# conv2d_2642 (Conv2D)            (None, 26, 26, 6)    10044       activation_2640[0][0]
# __________________________________________________________________________________________________
# dropout_2628 (Dropout)          (None, 26, 26, 6)    0           conv2d_2642[0][0]
# __________________________________________________________________________________________________
# concatenate_2590 (Concatenate)  (None, 26, 26, 192)  0           concatenate_2589[0][0]
#                                                                  dropout_2628[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2642 (Batch (None, 26, 26, 192)  768         concatenate_2590[0][0]
# __________________________________________________________________________________________________
# activation_2641 (Activation)    (None, 26, 26, 192)  0           batch_normalization_2642[0][0]
# __________________________________________________________________________________________________
# conv2d_2643 (Conv2D)            (None, 26, 26, 6)    10368       activation_2641[0][0]
# __________________________________________________________________________________________________
# dropout_2629 (Dropout)          (None, 26, 26, 6)    0           conv2d_2643[0][0]
# __________________________________________________________________________________________________
# concatenate_2591 (Concatenate)  (None, 26, 26, 198)  0           concatenate_2590[0][0]
#                                                                  dropout_2629[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2643 (Batch (None, 26, 26, 198)  792         concatenate_2591[0][0]
# __________________________________________________________________________________________________
# activation_2642 (Activation)    (None, 26, 26, 198)  0           batch_normalization_2643[0][0]
# __________________________________________________________________________________________________
# conv2d_2644 (Conv2D)            (None, 26, 26, 6)    10692       activation_2642[0][0]
# __________________________________________________________________________________________________
# dropout_2630 (Dropout)          (None, 26, 26, 6)    0           conv2d_2644[0][0]
# __________________________________________________________________________________________________
# concatenate_2592 (Concatenate)  (None, 26, 26, 204)  0           concatenate_2591[0][0]
#                                                                  dropout_2630[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2644 (Batch (None, 26, 26, 204)  816         concatenate_2592[0][0]
# __________________________________________________________________________________________________
# activation_2643 (Activation)    (None, 26, 26, 204)  0           batch_normalization_2644[0][0]
# __________________________________________________________________________________________________
# conv2d_2645 (Conv2D)            (None, 26, 26, 6)    11016       activation_2643[0][0]
# __________________________________________________________________________________________________
# dropout_2631 (Dropout)          (None, 26, 26, 6)    0           conv2d_2645[0][0]
# __________________________________________________________________________________________________
# concatenate_2593 (Concatenate)  (None, 26, 26, 210)  0           concatenate_2592[0][0]
#                                                                  dropout_2631[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2645 (Batch (None, 26, 26, 210)  840         concatenate_2593[0][0]
# __________________________________________________________________________________________________
# activation_2644 (Activation)    (None, 26, 26, 210)  0           batch_normalization_2645[0][0]
# __________________________________________________________________________________________________
# conv2d_2646 (Conv2D)            (None, 26, 26, 6)    11340       activation_2644[0][0]
# __________________________________________________________________________________________________
# dropout_2632 (Dropout)          (None, 26, 26, 6)    0           conv2d_2646[0][0]
# __________________________________________________________________________________________________
# concatenate_2594 (Concatenate)  (None, 26, 26, 216)  0           concatenate_2593[0][0]
#                                                                  dropout_2632[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2646 (Batch (None, 26, 26, 216)  864         concatenate_2594[0][0]
# __________________________________________________________________________________________________
# activation_2645 (Activation)    (None, 26, 26, 216)  0           batch_normalization_2646[0][0]
# __________________________________________________________________________________________________
# conv2d_2647 (Conv2D)            (None, 26, 26, 6)    11664       activation_2645[0][0]
# __________________________________________________________________________________________________
# dropout_2633 (Dropout)          (None, 26, 26, 6)    0           conv2d_2647[0][0]
# __________________________________________________________________________________________________
# concatenate_2595 (Concatenate)  (None, 26, 26, 222)  0           concatenate_2594[0][0]
#                                                                  dropout_2633[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2647 (Batch (None, 26, 26, 222)  888         concatenate_2595[0][0]
# __________________________________________________________________________________________________
# activation_2646 (Activation)    (None, 26, 26, 222)  0           batch_normalization_2647[0][0]
# __________________________________________________________________________________________________
# conv2d_2648 (Conv2D)            (None, 26, 26, 6)    11988       activation_2646[0][0]
# __________________________________________________________________________________________________
# dropout_2634 (Dropout)          (None, 26, 26, 6)    0           conv2d_2648[0][0]
# __________________________________________________________________________________________________
# concatenate_2596 (Concatenate)  (None, 26, 26, 228)  0           concatenate_2595[0][0]
#                                                                  dropout_2634[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2648 (Batch (None, 26, 26, 228)  912         concatenate_2596[0][0]
# __________________________________________________________________________________________________
# activation_2647 (Activation)    (None, 26, 26, 228)  0           batch_normalization_2648[0][0]
# __________________________________________________________________________________________________
# conv2d_2649 (Conv2D)            (None, 26, 26, 6)    12312       activation_2647[0][0]
# __________________________________________________________________________________________________
# dropout_2635 (Dropout)          (None, 26, 26, 6)    0           conv2d_2649[0][0]
# __________________________________________________________________________________________________
# concatenate_2597 (Concatenate)  (None, 26, 26, 234)  0           concatenate_2596[0][0]
#                                                                  dropout_2635[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2649 (Batch (None, 26, 26, 234)  936         concatenate_2597[0][0]
# __________________________________________________________________________________________________
# activation_2648 (Activation)    (None, 26, 26, 234)  0           batch_normalization_2649[0][0]
# __________________________________________________________________________________________________
# conv2d_2650 (Conv2D)            (None, 26, 26, 6)    12636       activation_2648[0][0]
# __________________________________________________________________________________________________
# dropout_2636 (Dropout)          (None, 26, 26, 6)    0           conv2d_2650[0][0]
# __________________________________________________________________________________________________
# concatenate_2598 (Concatenate)  (None, 26, 26, 240)  0           concatenate_2597[0][0]
#                                                                  dropout_2636[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2650 (Batch (None, 26, 26, 240)  960         concatenate_2598[0][0]
# __________________________________________________________________________________________________
# activation_2649 (Activation)    (None, 26, 26, 240)  0           batch_normalization_2650[0][0]
# __________________________________________________________________________________________________
# conv2d_2651 (Conv2D)            (None, 26, 26, 6)    12960       activation_2649[0][0]
# __________________________________________________________________________________________________
# dropout_2637 (Dropout)          (None, 26, 26, 6)    0           conv2d_2651[0][0]
# __________________________________________________________________________________________________
# concatenate_2599 (Concatenate)  (None, 26, 26, 246)  0           concatenate_2598[0][0]
#                                                                  dropout_2637[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2651 (Batch (None, 26, 26, 246)  984         concatenate_2599[0][0]
# __________________________________________________________________________________________________
# activation_2650 (Activation)    (None, 26, 26, 246)  0           batch_normalization_2651[0][0]
# __________________________________________________________________________________________________
# conv2d_2652 (Conv2D)            (None, 26, 26, 6)    13284       activation_2650[0][0]
# __________________________________________________________________________________________________
# dropout_2638 (Dropout)          (None, 26, 26, 6)    0           conv2d_2652[0][0]
# __________________________________________________________________________________________________
# concatenate_2600 (Concatenate)  (None, 26, 26, 252)  0           concatenate_2599[0][0]
#                                                                  dropout_2638[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2652 (Batch (None, 26, 26, 252)  1008        concatenate_2600[0][0]
# __________________________________________________________________________________________________
# activation_2651 (Activation)    (None, 26, 26, 252)  0           batch_normalization_2652[0][0]
# __________________________________________________________________________________________________
# conv2d_2653 (Conv2D)            (None, 26, 26, 6)    1512        activation_2651[0][0]
# __________________________________________________________________________________________________
# dropout_2639 (Dropout)          (None, 26, 26, 6)    0           conv2d_2653[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_51 (AveragePo (None, 13, 13, 6)    0           dropout_2639[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2653 (Batch (None, 13, 13, 6)    24          average_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# activation_2652 (Activation)    (None, 13, 13, 6)    0           batch_normalization_2653[0][0]
# __________________________________________________________________________________________________
# conv2d_2654 (Conv2D)            (None, 13, 13, 6)    324         activation_2652[0][0]
# __________________________________________________________________________________________________
# dropout_2640 (Dropout)          (None, 13, 13, 6)    0           conv2d_2654[0][0]
# __________________________________________________________________________________________________
# concatenate_2601 (Concatenate)  (None, 13, 13, 12)   0           average_pooling2d_51[0][0]
#                                                                  dropout_2640[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2654 (Batch (None, 13, 13, 12)   48          concatenate_2601[0][0]
# __________________________________________________________________________________________________
# activation_2653 (Activation)    (None, 13, 13, 12)   0           batch_normalization_2654[0][0]
# __________________________________________________________________________________________________
# conv2d_2655 (Conv2D)            (None, 13, 13, 6)    648         activation_2653[0][0]
# __________________________________________________________________________________________________
# dropout_2641 (Dropout)          (None, 13, 13, 6)    0           conv2d_2655[0][0]
# __________________________________________________________________________________________________
# concatenate_2602 (Concatenate)  (None, 13, 13, 18)   0           concatenate_2601[0][0]
#                                                                  dropout_2641[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2655 (Batch (None, 13, 13, 18)   72          concatenate_2602[0][0]
# __________________________________________________________________________________________________
# activation_2654 (Activation)    (None, 13, 13, 18)   0           batch_normalization_2655[0][0]
# __________________________________________________________________________________________________
# conv2d_2656 (Conv2D)            (None, 13, 13, 6)    972         activation_2654[0][0]
# ...
# conv2d_2734 (Conv2D)            (None, 6, 6, 6)      12960       activation_2732[0][0]
# __________________________________________________________________________________________________
# dropout_2720 (Dropout)          (None, 6, 6, 6)      0           conv2d_2734[0][0]
# __________________________________________________________________________________________________
# concatenate_2680 (Concatenate)  (None, 6, 6, 246)    0           concatenate_2679[0][0]
#                                                                  dropout_2720[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2734 (Batch (None, 6, 6, 246)    984         concatenate_2680[0][0]
# __________________________________________________________________________________________________
# activation_2733 (Activation)    (None, 6, 6, 246)    0           batch_normalization_2734[0][0]
# __________________________________________________________________________________________________
# conv2d_2735 (Conv2D)            (None, 6, 6, 6)      1476        activation_2733[0][0]
# __________________________________________________________________________________________________
# dropout_2721 (Dropout)          (None, 6, 6, 6)      0           conv2d_2735[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_53 (AveragePo (None, 3, 3, 6)      0           dropout_2721[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2735 (Batch (None, 3, 3, 6)      24          average_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# activation_2734 (Activation)    (None, 3, 3, 6)      0           batch_normalization_2735[0][0]
# __________________________________________________________________________________________________
# conv2d_2736 (Conv2D)            (None, 3, 3, 6)      324         activation_2734[0][0]
# __________________________________________________________________________________________________
# dropout_2722 (Dropout)          (None, 3, 3, 6)      0           conv2d_2736[0][0]
# __________________________________________________________________________________________________
# concatenate_2681 (Concatenate)  (None, 3, 3, 12)     0           average_pooling2d_53[0][0]
#                                                                  dropout_2722[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2736 (Batch (None, 3, 3, 12)     48          concatenate_2681[0][0]
# __________________________________________________________________________________________________
# activation_2735 (Activation)    (None, 3, 3, 12)     0           batch_normalization_2736[0][0]
# __________________________________________________________________________________________________
# conv2d_2737 (Conv2D)            (None, 3, 3, 6)      648         activation_2735[0][0]
# __________________________________________________________________________________________________
# dropout_2723 (Dropout)          (None, 3, 3, 6)      0           conv2d_2737[0][0]
# __________________________________________________________________________________________________
# concatenate_2682 (Concatenate)  (None, 3, 3, 18)     0           concatenate_2681[0][0]
#                                                                  dropout_2723[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2737 (Batch (None, 3, 3, 18)     72          concatenate_2682[0][0]
# __________________________________________________________________________________________________
# activation_2736 (Activation)    (None, 3, 3, 18)     0           batch_normalization_2737[0][0]
# __________________________________________________________________________________________________
# conv2d_2738 (Conv2D)            (None, 3, 3, 6)      972         activation_2736[0][0]
# __________________________________________________________________________________________________
# dropout_2724 (Dropout)          (None, 3, 3, 6)      0           conv2d_2738[0][0]
# __________________________________________________________________________________________________
# concatenate_2683 (Concatenate)  (None, 3, 3, 24)     0           concatenate_2682[0][0]
#                                                                  dropout_2724[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2738 (Batch (None, 3, 3, 24)     96          concatenate_2683[0][0]
# __________________________________________________________________________________________________
# activation_2737 (Activation)    (None, 3, 3, 24)     0           batch_normalization_2738[0][0]
# __________________________________________________________________________________________________
# conv2d_2739 (Conv2D)            (None, 3, 3, 6)      1296        activation_2737[0][0]
# __________________________________________________________________________________________________
# dropout_2725 (Dropout)          (None, 3, 3, 6)      0           conv2d_2739[0][0]
# __________________________________________________________________________________________________
# concatenate_2684 (Concatenate)  (None, 3, 3, 30)     0           concatenate_2683[0][0]
#                                                                  dropout_2725[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2739 (Batch (None, 3, 3, 30)     120         concatenate_2684[0][0]
# __________________________________________________________________________________________________
# activation_2738 (Activation)    (None, 3, 3, 30)     0           batch_normalization_2739[0][0]
# __________________________________________________________________________________________________
# conv2d_2740 (Conv2D)            (None, 3, 3, 6)      1620        activation_2738[0][0]
# __________________________________________________________________________________________________
# dropout_2726 (Dropout)          (None, 3, 3, 6)      0           conv2d_2740[0][0]
# __________________________________________________________________________________________________
# concatenate_2685 (Concatenate)  (None, 3, 3, 36)     0           concatenate_2684[0][0]
#                                                                  dropout_2726[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2740 (Batch (None, 3, 3, 36)     144         concatenate_2685[0][0]
# __________________________________________________________________________________________________
# activation_2739 (Activation)    (None, 3, 3, 36)     0           batch_normalization_2740[0][0]
# __________________________________________________________________________________________________
# conv2d_2741 (Conv2D)            (None, 3, 3, 6)      1944        activation_2739[0][0]
# __________________________________________________________________________________________________
# dropout_2727 (Dropout)          (None, 3, 3, 6)      0           conv2d_2741[0][0]
# __________________________________________________________________________________________________
# concatenate_2686 (Concatenate)  (None, 3, 3, 42)     0           concatenate_2685[0][0]
#                                                                  dropout_2727[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2741 (Batch (None, 3, 3, 42)     168         concatenate_2686[0][0]
# __________________________________________________________________________________________________
# activation_2740 (Activation)    (None, 3, 3, 42)     0           batch_normalization_2741[0][0]
# __________________________________________________________________________________________________
# conv2d_2742 (Conv2D)            (None, 3, 3, 6)      2268        activation_2740[0][0]
# __________________________________________________________________________________________________
# dropout_2728 (Dropout)          (None, 3, 3, 6)      0           conv2d_2742[0][0]
# __________________________________________________________________________________________________
# concatenate_2687 (Concatenate)  (None, 3, 3, 48)     0           concatenate_2686[0][0]
#                                                                  dropout_2728[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2742 (Batch (None, 3, 3, 48)     192         concatenate_2687[0][0]
# __________________________________________________________________________________________________
# activation_2741 (Activation)    (None, 3, 3, 48)     0           batch_normalization_2742[0][0]
# __________________________________________________________________________________________________
# conv2d_2743 (Conv2D)            (None, 3, 3, 6)      2592        activation_2741[0][0]
# __________________________________________________________________________________________________
# dropout_2729 (Dropout)          (None, 3, 3, 6)      0           conv2d_2743[0][0]
# __________________________________________________________________________________________________
# concatenate_2688 (Concatenate)  (None, 3, 3, 54)     0           concatenate_2687[0][0]
#                                                                  dropout_2729[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2743 (Batch (None, 3, 3, 54)     216         concatenate_2688[0][0]
# __________________________________________________________________________________________________
# activation_2742 (Activation)    (None, 3, 3, 54)     0           batch_normalization_2743[0][0]
# __________________________________________________________________________________________________
# conv2d_2744 (Conv2D)            (None, 3, 3, 6)      2916        activation_2742[0][0]
# __________________________________________________________________________________________________
# dropout_2730 (Dropout)          (None, 3, 3, 6)      0           conv2d_2744[0][0]
# __________________________________________________________________________________________________
# concatenate_2689 (Concatenate)  (None, 3, 3, 60)     0           concatenate_2688[0][0]
#                                                                  dropout_2730[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2744 (Batch (None, 3, 3, 60)     240         concatenate_2689[0][0]
# __________________________________________________________________________________________________
# activation_2743 (Activation)    (None, 3, 3, 60)     0           batch_normalization_2744[0][0]
# __________________________________________________________________________________________________
# conv2d_2745 (Conv2D)            (None, 3, 3, 6)      3240        activation_2743[0][0]
# __________________________________________________________________________________________________
# dropout_2731 (Dropout)          (None, 3, 3, 6)      0           conv2d_2745[0][0]
# __________________________________________________________________________________________________
# concatenate_2690 (Concatenate)  (None, 3, 3, 66)     0           concatenate_2689[0][0]
#                                                                  dropout_2731[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2745 (Batch (None, 3, 3, 66)     264         concatenate_2690[0][0]
# __________________________________________________________________________________________________
# activation_2744 (Activation)    (None, 3, 3, 66)     0           batch_normalization_2745[0][0]
# __________________________________________________________________________________________________
# conv2d_2746 (Conv2D)            (None, 3, 3, 6)      3564        activation_2744[0][0]
# __________________________________________________________________________________________________
# dropout_2732 (Dropout)          (None, 3, 3, 6)      0           conv2d_2746[0][0]
# __________________________________________________________________________________________________
# concatenate_2691 (Concatenate)  (None, 3, 3, 72)     0           concatenate_2690[0][0]
#                                                                  dropout_2732[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2746 (Batch (None, 3, 3, 72)     288         concatenate_2691[0][0]
# __________________________________________________________________________________________________
# activation_2745 (Activation)    (None, 3, 3, 72)     0           batch_normalization_2746[0][0]
# __________________________________________________________________________________________________
# conv2d_2747 (Conv2D)            (None, 3, 3, 6)      3888        activation_2745[0][0]
# __________________________________________________________________________________________________
# dropout_2733 (Dropout)          (None, 3, 3, 6)      0           conv2d_2747[0][0]
# __________________________________________________________________________________________________
# concatenate_2692 (Concatenate)  (None, 3, 3, 78)     0           concatenate_2691[0][0]
#                                                                  dropout_2733[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2747 (Batch (None, 3, 3, 78)     312         concatenate_2692[0][0]
# __________________________________________________________________________________________________
# activation_2746 (Activation)    (None, 3, 3, 78)     0           batch_normalization_2747[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_54 (AveragePo (None, 1, 1, 78)     0           activation_2746[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 78)           0           average_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           790         flatten_13[0][0]
# ==================================================================================================
# Total params: 906,010
# Trainable params: 873,430
# Non-trainable params: 32,580
# __________________________________________________________________________________________________

# %%
#train model
hs=model_small.fit(x_train, y_train, batch_size=batch_size,verbose=1,
                    epochs=model_small_epochs, callbacks=callbacks,
                    validation_data=(x_test, y_test))
model_small.save(model_file)
print('Saved model_small to disk')
# Out:
# Train on 87500 samples, validate on 10000 samples

# %%
print('====================END OF SMALLER MODEL====================')

# %%
print('====================BEGIN OF LARGER MODEL====================')

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=True,shape=smaller_input[:-1])

#callbacks
model_checkpointer=ModelCheckpoint('large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.1, max_lr=0.2,step_size=8*(len(y_train)/batch_size),mode='triangular2',gamma=0.99994)

M = 6
nb_epoch = T = 200
alpha_zero = 0.1
model_prefix = 'ensemble_'
snapshot = SnapshotCallbackBuilder(T, M, alpha_zero) 


# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
callbacks = [clr, model_checkpointer]

# %%
#create model
model_prev=load_prev_model(model_small)

# model_large = create_model(x_train.shape[1:],num_layers=layers_large,input=model_prev.output)
model_large = larger_model(model_prev)

model_large.compile(loss='categorical_crossentropy',metrics=['accuracy'],
                    optimizer=SGD(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True))
model_large.summary()

# %%
#train model
hl=model_large.fit(x_train, y_train, batch_size=batch_size, verbose=1,
                epochs=model_large_epochs1, callbacks=callbacks,
                validation_data=(x_test, y_test))
model_large.save(model_file)
print("Saved model to disk")

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=True,shape=smaller_input[:-1])

#callbacks
model_checkpointer=ModelCheckpoint('large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',
                verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
clr = CyclicLR(base_lr=0.001, max_lr=0.2,step_size=8*(len(y_train)/batch_size),mode='triangular2',gamma=0.99994)

M = 6
nb_epoch = T = 200
alpha_zero = 0.1
model_prefix = 'ensemble_'
snapshot = SnapshotCallbackBuilder(T, M, alpha_zero) 


# callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
callbacks = [clr, model_checkpointer]

# %%
#train model
hl2=model_large.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_large_epochs1,
                epochs=model_large_epochs1+model_large_epochs2, callbacks=callbacks,
                validation_data=(x_test, y_test))
model_large.save(model_file)
print("Saved model to disk")

# %%
# Test the model
score = model_large.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
print('====================END OF LARGER MODEL====================')

# %%
score = model_large.evaluate(x_test, y_test, verbose=1)
s=open('res.txt','w')
s.write(score[0],score[1])
s.close()

# %%
s=open('res.txt','a')
s.write(str(hl))
s.close()
