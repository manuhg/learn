# %%
# !pip install -q six numpy scipy matplotlib scikit-image opencv-python imageio
# !pip install -q keras imgaug
# !pip install -q git+https://www.github.com/keras-team/keras-contrib.git

# %%
import keras
from keras_contrib.callbacks import CyclicLR, DeadReluDetector, SnapshotCallbackBuilder, SnapshotModelCheckpoint
import imgaug as ia
from imgaug import augmenters as iaa
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import SGD
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
# from keras.callbacks import LearningRateScheduler,ModelCheckpoint,EarlyStopping,LambdaCallback
import os,sys,math

# %%
import google
colab_dir='./'
file_name='EIP_CIFAR_10'
if hasattr(google,'colab'):
    from google.colab import drive
    drive.mount('/content/gdrive')
    colab_dir='/content/gdrive/My Drive/Colab Notebooks/'
model_file=colab_dir+file_name+'.h5'
weights_dir=colab_dir+'weights/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
#Augmentation and resizing
#augment and then concat samples with original
def augment(dataset,flip=0.5,blur=1.0):
    ia.seed(1)
#     seq = iaa.Sequential([iaa.Fliplr(flip),iaa.GaussianBlur(sigma=(0, blur)),iaa.Sometimes(iaa.Crop(percent=(0, 0.1))),
#                          iaa.Sometimes(iaa.Affine(scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
#                                              translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
#                                              rotate=(-45, 45),shear=(-16, 16),order=[0, 1],cval=(0, 255),mode=ia.ALL))])
    seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0, 0.1)),
    iaa.Sometimes(0.5,
        iaa.GaussianBlur(sigma=(0, 0.5))
    ),
    iaa.ContrastNormalization((0.75, 1.5)),
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5),
    iaa.Multiply((0.8, 1.2), per_channel=0.2),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8))], random_order=True)    
    return seq.augment_images(dataset)

def augmenter(X,y,start=0,end=1):
    na=True
    ln=len(X)
    print('Before augmentation:',X.shape,y.shape)
    start=int(start*ln)
    end=int(end*ln)
    if na:
      X=augment(X)
    else:
      new_X=augment(X)[start:end]
      new_y=y[start:end]
      X=np.concatenate((X,new_X))
      y=np.concatenate((y,new_y))
    print('After augmentation:',X.shape,y.shape)
    return (X,y)

#26x26 is almost half of 32x32. 22x22 maybe too small even though its exact half.
def resize_imgs(imgs,shape=(26,26)):
    seq = iaa.Sequential([iaa.Scale({"height": shape[0], "width": shape[1]})])
    return seq.augment_images(imgs)

# %%
# Dense Block
def add_denseblock(input, num_filter = 12, dropout_rate = 0.2,num_layers=12):
    global compression
    temp = input
    for _ in range(num_layers):
        BatchNorm = BatchNormalization()(temp)
        relu = Activation('relu')(BatchNorm)
        Conv2D_3_3 = Conv2D(int(num_filter*compression), (3,3),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
        if dropout_rate>0:
            Conv2D_3_3 = Dropout(dropout_rate)(Conv2D_3_3)
        concat = Concatenate(axis=-1)([temp,Conv2D_3_3])        
        temp = concat        
    return temp

def add_transition(input, num_filter = 12, dropout_rate = 0.2):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    Conv2D_BottleNeck = Conv2D(int(num_filter*compression), (1,1),kernel_initializer='he_normal', use_bias=False ,padding='same')(relu)
    if dropout_rate>0:
        Conv2D_BottleNeck = Dropout(dropout_rate)(Conv2D_BottleNeck)
    avg = AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)    
    return avg

def output_layer(input):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    AvgPooling = AveragePooling2D(pool_size=(2,2))(relu)
    flat = Flatten()(AvgPooling)
    output = Dense(num_classes, activation='softmax')(flat)    
    return output
  
def dense_unit(input_layer,num_filter, dropout_rate,num_layers):
    dense_block=add_denseblock(input_layer, num_filter, dropout_rate,num_layers)
    transition_block=add_transition(dense_block, num_filter, dropout_rate)
    return transition_block
  
def dense_units_chain(n,input_layer,num_filter, dropout_rate,num_layers):
    dense_unit_=input_layer
    for i in range(n):
        dense_unit_=dense_unit(dense_unit_,num_filter, dropout_rate,num_layers)
    return dense_unit_

# %%
def load_prev_model(model_small=None):
#     print(os.popen('du -sh '+colab_dir+'*').read())
    last_best=os.popen('du -sh '+colab_dir+r'*|sed -r "s/^[0-9\.]+[MK]?\s(.*)$/\1/g;"|tail -1').read().strip()
    model_prev=None
    try:
        print('Attempting to load last best model from file - ',end='')
        last_best_fn=last_best.split('/')[-1]
        last_best_epoch=last_best_fn.split('.')[1].split('-')[0]
        model_prev=load_model(last_best)
        print('Sucess\nLoaded '+last_best_fn, 'epoch :', last_best_epoch)
    except Exception as e:
        print('Failed!\n',e)
        try:
            print('Attempting to load last saved model from file - ',end='')
            model_prev = load_model(model_file)
            print('Sucess\nLoaded model from file',model_file)
        except Exception as e:
    #         print(str(e), 'at line ', sys.exc_info()[2].tb_lineno)
            print('Failed!\n',e)
            try:
                print('Attempting to load in memory, small model - ',end='')
                if len(model_small.layers)>1:
                    model_prev=model_small
                print('Sucess')
            except Exception as e:
                print('Failed!\n',e)
    return model_prev
  
def copy_weights(model_to,model_from):
    #model_to.set_weights(model_from.get_weights())
    s,err=0,0
    print('Trying to copy weights')
    try:
        if len(model_to.layers) >1 and len(model_from.layers) >1:
            pass
    except Exception as e:
        print('Inavlid models',model_to,model_from)
        return
    for new_layer, layer in zip(model_to.layers[1:], model_from.layers[1:]):
        s+=1
        try:
            new_layer.set_weights(layer.get_weights())
        except Exception as e:
            pass
    print('Done: errors:',err)
      
#new model with larger i/p layer
def larger_model(src_model,shape=(32,32,3)):
    new_input=Input(shape)
    src_model.layers.pop(0)
    new_output=src_model(new_input)
    new_model=Model(new_input,new_output)
    return new_model

# Load CIFAR10 Data
def load_data(resize=False,shape=(26,26),test_augment=False):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    
    if resize:
        x_train=resize_imgs(x_train,shape)
        x_test=resize_imgs(x_test,shape)
    
    (x_train, y_train) = augmenter(x_train, y_train,end=1)
    if test_augment:
        (x_test, y_test) = augmenter(x_test, y_test,end=1)
    return (x_train, y_train,x_test, y_test)
#create a dnn model
def create_model(input_shape,num_layers,input=None):
    print('Creating model with input shape',input_shape)
    if input is None:
        input = Input(input_shape)
    First_Conv2D = Conv2D(num_filter, (3,3), use_bias=False ,padding='same')(input)
    hidden_dense_blocks = dense_units_chain(n_dense_blocks,First_Conv2D,num_filter,dropout_rate,num_layers)
    Last_Block = add_denseblock(hidden_dense_blocks, num_filter, dropout_rate)
    output = output_layer(Last_Block)
    model = Model(inputs=[input], outputs=[output])
    return model

# %%
print('====================HYPER PARAMETERS====================')
# Out:
# ====================HYPER PARAMETERS====================

# %%
# Hyperparameters
batch_size = 128
num_classes = 10
max_epochs = 250

model_epochs=[[0,15],[0,50],[50,80]]
num_layers = 32

layers_large=layers_small=num_layers
num_filter = 12
compression = 0.6
dropout_rate = 0.2
n_dense_blocks = 3
smaller_input=(26,26,3)
hist=[]
i=-1

# %%
print('====================BEGIN OF SMALLER MODEL====================')
# Out:
# ====================BEGIN OF SMALLER MODEL====================

# %%
# #load data
# x_train, y_train, x_test, y_test = load_data(resize=True,shape=smaller_input[:-1])

# #callbacks
# model_checkpointer=ModelCheckpoint(weights_dir+'small_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)

# clr = CyclicLR(base_lr=0.1, max_lr=0.2,step_size=8*(len(y_train)/batch_size))

# # callbacks = snapshot.get_callbacks(model_prefix=model_prefix)
# callbacks = [clr, model_checkpointer]

# %%
# #create model
# model_small = create_model((x_train.shape[1:]),num_layers=layers_small)
# model_small.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=SGD(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True))
# model_small.summary()

# %%
# #train model
i+=1
# h=model_small.fit(x_train, y_train, batch_size=batch_size,verbose=1,initial_epoch=model_epochs[i][0],epochs=model_epochs[i][1], callbacks=callbacks,validation_data=(x_test, y_test))
# hist.append(h)
# model_small.save(model_file)
# print('Saved model_small to disk')

# %%
print('====================END OF SMALLER MODEL====================')
# Out:
# ====================END OF SMALLER MODEL====================

# %%
print('====================BEGIN OF LARGER MODEL====================')
# Out:
# ====================BEGIN OF LARGER MODEL====================

# %%
#load data
x_train, y_train, x_test, y_test = load_data(resize=False)
#callbacks
model_checkpointer=ModelCheckpoint(weights_dir+'large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
clr = CyclicLR(base_lr=0.1, max_lr=0.3,step_size=8*(len(y_train)/batch_size),mode='exp_range',gamma=0.99994)

callbacks = [ model_checkpointer]
# Out:
# Before augmentation: (50000, 32, 32, 3) (50000, 10)
# After augmentation: (50000, 32, 32, 3) (50000, 10)

# %%
#create model
# model_prev=load_prev_model(model_small)
model_large1 = create_model(x_train.shape[1:],num_layers=layers_large)
# copy_weights(model_large,model_prev)
model_large1.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=SGD(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True))
model_large1.summary()
# Out:
# Creating model with input shape (32, 32, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_698 (Conv2D)             (None, 32, 32, 12)   324         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_698 (BatchN (None, 32, 32, 12)   48          conv2d_698[0][0]
# __________________________________________________________________________________________________
# activation_698 (Activation)     (None, 32, 32, 12)   0           batch_normalization_698[0][0]
# __________________________________________________________________________________________________
# conv2d_699 (Conv2D)             (None, 32, 32, 7)    756         activation_698[0][0]
# __________________________________________________________________________________________________
# dropout_691 (Dropout)           (None, 32, 32, 7)    0           conv2d_699[0][0]
# __________________________________________________________________________________________________
# concatenate_670 (Concatenate)   (None, 32, 32, 19)   0           conv2d_698[0][0]
#                                                                  dropout_691[0][0]
# __________________________________________________________________________________________________
# batch_normalization_699 (BatchN (None, 32, 32, 19)   76          concatenate_670[0][0]
# __________________________________________________________________________________________________
# activation_699 (Activation)     (None, 32, 32, 19)   0           batch_normalization_699[0][0]
# __________________________________________________________________________________________________
# conv2d_700 (Conv2D)             (None, 32, 32, 7)    1197        activation_699[0][0]
# __________________________________________________________________________________________________
# dropout_692 (Dropout)           (None, 32, 32, 7)    0           conv2d_700[0][0]
# __________________________________________________________________________________________________
# concatenate_671 (Concatenate)   (None, 32, 32, 26)   0           concatenate_670[0][0]
#                                                                  dropout_692[0][0]
# __________________________________________________________________________________________________
# batch_normalization_700 (BatchN (None, 32, 32, 26)   104         concatenate_671[0][0]
# __________________________________________________________________________________________________
# activation_700 (Activation)     (None, 32, 32, 26)   0           batch_normalization_700[0][0]
# __________________________________________________________________________________________________
# conv2d_701 (Conv2D)             (None, 32, 32, 7)    1638        activation_700[0][0]
# __________________________________________________________________________________________________
# dropout_693 (Dropout)           (None, 32, 32, 7)    0           conv2d_701[0][0]
# __________________________________________________________________________________________________
# concatenate_672 (Concatenate)   (None, 32, 32, 33)   0           concatenate_671[0][0]
#                                                                  dropout_693[0][0]
# __________________________________________________________________________________________________
# batch_normalization_701 (BatchN (None, 32, 32, 33)   132         concatenate_672[0][0]
# __________________________________________________________________________________________________
# activation_701 (Activation)     (None, 32, 32, 33)   0           batch_normalization_701[0][0]
# __________________________________________________________________________________________________
# conv2d_702 (Conv2D)             (None, 32, 32, 7)    2079        activation_701[0][0]
# __________________________________________________________________________________________________
# dropout_694 (Dropout)           (None, 32, 32, 7)    0           conv2d_702[0][0]
# __________________________________________________________________________________________________
# concatenate_673 (Concatenate)   (None, 32, 32, 40)   0           concatenate_672[0][0]
#                                                                  dropout_694[0][0]
# __________________________________________________________________________________________________
# batch_normalization_702 (BatchN (None, 32, 32, 40)   160         concatenate_673[0][0]
# __________________________________________________________________________________________________
# activation_702 (Activation)     (None, 32, 32, 40)   0           batch_normalization_702[0][0]
# __________________________________________________________________________________________________
# conv2d_703 (Conv2D)             (None, 32, 32, 7)    2520        activation_702[0][0]
# __________________________________________________________________________________________________
# dropout_695 (Dropout)           (None, 32, 32, 7)    0           conv2d_703[0][0]
# __________________________________________________________________________________________________
# concatenate_674 (Concatenate)   (None, 32, 32, 47)   0           concatenate_673[0][0]
#                                                                  dropout_695[0][0]
# __________________________________________________________________________________________________
# batch_normalization_703 (BatchN (None, 32, 32, 47)   188         concatenate_674[0][0]
# __________________________________________________________________________________________________
# activation_703 (Activation)     (None, 32, 32, 47)   0           batch_normalization_703[0][0]
# __________________________________________________________________________________________________
# conv2d_704 (Conv2D)             (None, 32, 32, 7)    2961        activation_703[0][0]
# __________________________________________________________________________________________________
# dropout_696 (Dropout)           (None, 32, 32, 7)    0           conv2d_704[0][0]
# __________________________________________________________________________________________________
# concatenate_675 (Concatenate)   (None, 32, 32, 54)   0           concatenate_674[0][0]
#                                                                  dropout_696[0][0]
# __________________________________________________________________________________________________
# batch_normalization_704 (BatchN (None, 32, 32, 54)   216         concatenate_675[0][0]
# __________________________________________________________________________________________________
# activation_704 (Activation)     (None, 32, 32, 54)   0           batch_normalization_704[0][0]
# __________________________________________________________________________________________________
# conv2d_705 (Conv2D)             (None, 32, 32, 7)    3402        activation_704[0][0]
# __________________________________________________________________________________________________
# dropout_697 (Dropout)           (None, 32, 32, 7)    0           conv2d_705[0][0]
# __________________________________________________________________________________________________
# concatenate_676 (Concatenate)   (None, 32, 32, 61)   0           concatenate_675[0][0]
#                                                                  dropout_697[0][0]
# __________________________________________________________________________________________________
# batch_normalization_705 (BatchN (None, 32, 32, 61)   244         concatenate_676[0][0]
# __________________________________________________________________________________________________
# activation_705 (Activation)     (None, 32, 32, 61)   0           batch_normalization_705[0][0]
# __________________________________________________________________________________________________
# conv2d_706 (Conv2D)             (None, 32, 32, 7)    3843        activation_705[0][0]
# __________________________________________________________________________________________________
# dropout_698 (Dropout)           (None, 32, 32, 7)    0           conv2d_706[0][0]
# __________________________________________________________________________________________________
# concatenate_677 (Concatenate)   (None, 32, 32, 68)   0           concatenate_676[0][0]
#                                                                  dropout_698[0][0]
# __________________________________________________________________________________________________
# batch_normalization_706 (BatchN (None, 32, 32, 68)   272         concatenate_677[0][0]
# __________________________________________________________________________________________________
# activation_706 (Activation)     (None, 32, 32, 68)   0           batch_normalization_706[0][0]
# __________________________________________________________________________________________________
# conv2d_707 (Conv2D)             (None, 32, 32, 7)    4284        activation_706[0][0]
# __________________________________________________________________________________________________
# dropout_699 (Dropout)           (None, 32, 32, 7)    0           conv2d_707[0][0]
# __________________________________________________________________________________________________
# concatenate_678 (Concatenate)   (None, 32, 32, 75)   0           concatenate_677[0][0]
#                                                                  dropout_699[0][0]
# __________________________________________________________________________________________________
# batch_normalization_707 (BatchN (None, 32, 32, 75)   300         concatenate_678[0][0]
# __________________________________________________________________________________________________
# activation_707 (Activation)     (None, 32, 32, 75)   0           batch_normalization_707[0][0]
# __________________________________________________________________________________________________
# conv2d_708 (Conv2D)             (None, 32, 32, 7)    4725        activation_707[0][0]
# __________________________________________________________________________________________________
# dropout_700 (Dropout)           (None, 32, 32, 7)    0           conv2d_708[0][0]
# __________________________________________________________________________________________________
# concatenate_679 (Concatenate)   (None, 32, 32, 82)   0           concatenate_678[0][0]
#                                                                  dropout_700[0][0]
# __________________________________________________________________________________________________
# batch_normalization_708 (BatchN (None, 32, 32, 82)   328         concatenate_679[0][0]
# __________________________________________________________________________________________________
# activation_708 (Activation)     (None, 32, 32, 82)   0           batch_normalization_708[0][0]
# __________________________________________________________________________________________________
# conv2d_709 (Conv2D)             (None, 32, 32, 7)    5166        activation_708[0][0]
# __________________________________________________________________________________________________
# dropout_701 (Dropout)           (None, 32, 32, 7)    0           conv2d_709[0][0]
# __________________________________________________________________________________________________
# concatenate_680 (Concatenate)   (None, 32, 32, 89)   0           concatenate_679[0][0]
#                                                                  dropout_701[0][0]
# __________________________________________________________________________________________________
# batch_normalization_709 (BatchN (None, 32, 32, 89)   356         concatenate_680[0][0]
# __________________________________________________________________________________________________
# activation_709 (Activation)     (None, 32, 32, 89)   0           batch_normalization_709[0][0]
# __________________________________________________________________________________________________
# conv2d_710 (Conv2D)             (None, 32, 32, 7)    5607        activation_709[0][0]
# __________________________________________________________________________________________________
# dropout_702 (Dropout)           (None, 32, 32, 7)    0           conv2d_710[0][0]
# __________________________________________________________________________________________________
# concatenate_681 (Concatenate)   (None, 32, 32, 96)   0           concatenate_680[0][0]
#                                                                  dropout_702[0][0]
# __________________________________________________________________________________________________
# batch_normalization_710 (BatchN (None, 32, 32, 96)   384         concatenate_681[0][0]
# __________________________________________________________________________________________________
# activation_710 (Activation)     (None, 32, 32, 96)   0           batch_normalization_710[0][0]
# __________________________________________________________________________________________________
# conv2d_711 (Conv2D)             (None, 32, 32, 7)    6048        activation_710[0][0]
# __________________________________________________________________________________________________
# dropout_703 (Dropout)           (None, 32, 32, 7)    0           conv2d_711[0][0]
# __________________________________________________________________________________________________
# concatenate_682 (Concatenate)   (None, 32, 32, 103)  0           concatenate_681[0][0]
#                                                                  dropout_703[0][0]
# __________________________________________________________________________________________________
# batch_normalization_711 (BatchN (None, 32, 32, 103)  412         concatenate_682[0][0]
# __________________________________________________________________________________________________
# activation_711 (Activation)     (None, 32, 32, 103)  0           batch_normalization_711[0][0]
# __________________________________________________________________________________________________
# conv2d_712 (Conv2D)             (None, 32, 32, 7)    6489        activation_711[0][0]
# __________________________________________________________________________________________________
# dropout_704 (Dropout)           (None, 32, 32, 7)    0           conv2d_712[0][0]
# __________________________________________________________________________________________________
# concatenate_683 (Concatenate)   (None, 32, 32, 110)  0           concatenate_682[0][0]
#                                                                  dropout_704[0][0]
# __________________________________________________________________________________________________
# batch_normalization_712 (BatchN (None, 32, 32, 110)  440         concatenate_683[0][0]
# __________________________________________________________________________________________________
# activation_712 (Activation)     (None, 32, 32, 110)  0           batch_normalization_712[0][0]
# __________________________________________________________________________________________________
# conv2d_713 (Conv2D)             (None, 32, 32, 7)    6930        activation_712[0][0]
# __________________________________________________________________________________________________
# dropout_705 (Dropout)           (None, 32, 32, 7)    0           conv2d_713[0][0]
# __________________________________________________________________________________________________
# concatenate_684 (Concatenate)   (None, 32, 32, 117)  0           concatenate_683[0][0]
#                                                                  dropout_705[0][0]
# __________________________________________________________________________________________________
# batch_normalization_713 (BatchN (None, 32, 32, 117)  468         concatenate_684[0][0]
# __________________________________________________________________________________________________
# activation_713 (Activation)     (None, 32, 32, 117)  0           batch_normalization_713[0][0]
# __________________________________________________________________________________________________
# conv2d_714 (Conv2D)             (None, 32, 32, 7)    7371        activation_713[0][0]
# __________________________________________________________________________________________________
# dropout_706 (Dropout)           (None, 32, 32, 7)    0           conv2d_714[0][0]
# __________________________________________________________________________________________________
# concatenate_685 (Concatenate)   (None, 32, 32, 124)  0           concatenate_684[0][0]
#                                                                  dropout_706[0][0]
# __________________________________________________________________________________________________
# batch_normalization_714 (BatchN (None, 32, 32, 124)  496         concatenate_685[0][0]
# __________________________________________________________________________________________________
# activation_714 (Activation)     (None, 32, 32, 124)  0           batch_normalization_714[0][0]
# __________________________________________________________________________________________________
# conv2d_715 (Conv2D)             (None, 32, 32, 7)    7812        activation_714[0][0]
# __________________________________________________________________________________________________
# dropout_707 (Dropout)           (None, 32, 32, 7)    0           conv2d_715[0][0]
# __________________________________________________________________________________________________
# concatenate_686 (Concatenate)   (None, 32, 32, 131)  0           concatenate_685[0][0]
#                                                                  dropout_707[0][0]
# __________________________________________________________________________________________________
# batch_normalization_715 (BatchN (None, 32, 32, 131)  524         concatenate_686[0][0]
# __________________________________________________________________________________________________
# activation_715 (Activation)     (None, 32, 32, 131)  0           batch_normalization_715[0][0]
# __________________________________________________________________________________________________
# conv2d_716 (Conv2D)             (None, 32, 32, 7)    8253        activation_715[0][0]
# __________________________________________________________________________________________________
# dropout_708 (Dropout)           (None, 32, 32, 7)    0           conv2d_716[0][0]
# __________________________________________________________________________________________________
# concatenate_687 (Concatenate)   (None, 32, 32, 138)  0           concatenate_686[0][0]
#                                                                  dropout_708[0][0]
# __________________________________________________________________________________________________
# batch_normalization_716 (BatchN (None, 32, 32, 138)  552         concatenate_687[0][0]
# __________________________________________________________________________________________________
# activation_716 (Activation)     (None, 32, 32, 138)  0           batch_normalization_716[0][0]
# __________________________________________________________________________________________________
# conv2d_717 (Conv2D)             (None, 32, 32, 7)    8694        activation_716[0][0]
# __________________________________________________________________________________________________
# dropout_709 (Dropout)           (None, 32, 32, 7)    0           conv2d_717[0][0]
# __________________________________________________________________________________________________
# concatenate_688 (Concatenate)   (None, 32, 32, 145)  0           concatenate_687[0][0]
#                                                                  dropout_709[0][0]
# __________________________________________________________________________________________________
# batch_normalization_717 (BatchN (None, 32, 32, 145)  580         concatenate_688[0][0]
# __________________________________________________________________________________________________
# activation_717 (Activation)     (None, 32, 32, 145)  0           batch_normalization_717[0][0]
# __________________________________________________________________________________________________
# conv2d_718 (Conv2D)             (None, 32, 32, 7)    9135        activation_717[0][0]
# __________________________________________________________________________________________________
# dropout_710 (Dropout)           (None, 32, 32, 7)    0           conv2d_718[0][0]
# __________________________________________________________________________________________________
# concatenate_689 (Concatenate)   (None, 32, 32, 152)  0           concatenate_688[0][0]
#                                                                  dropout_710[0][0]
# __________________________________________________________________________________________________
# batch_normalization_718 (BatchN (None, 32, 32, 152)  608         concatenate_689[0][0]
# __________________________________________________________________________________________________
# activation_718 (Activation)     (None, 32, 32, 152)  0           batch_normalization_718[0][0]
# __________________________________________________________________________________________________
# conv2d_719 (Conv2D)             (None, 32, 32, 7)    9576        activation_718[0][0]
# __________________________________________________________________________________________________
# dropout_711 (Dropout)           (None, 32, 32, 7)    0           conv2d_719[0][0]
# __________________________________________________________________________________________________
# concatenate_690 (Concatenate)   (None, 32, 32, 159)  0           concatenate_689[0][0]
#                                                                  dropout_711[0][0]
# __________________________________________________________________________________________________
# batch_normalization_719 (BatchN (None, 32, 32, 159)  636         concatenate_690[0][0]
# __________________________________________________________________________________________________
# activation_719 (Activation)     (None, 32, 32, 159)  0           batch_normalization_719[0][0]
# __________________________________________________________________________________________________
# conv2d_720 (Conv2D)             (None, 32, 32, 7)    10017       activation_719[0][0]
# __________________________________________________________________________________________________
# dropout_712 (Dropout)           (None, 32, 32, 7)    0           conv2d_720[0][0]
# __________________________________________________________________________________________________
# concatenate_691 (Concatenate)   (None, 32, 32, 166)  0           concatenate_690[0][0]
#                                                                  dropout_712[0][0]
# __________________________________________________________________________________________________
# batch_normalization_720 (BatchN (None, 32, 32, 166)  664         concatenate_691[0][0]
# __________________________________________________________________________________________________
# activation_720 (Activation)     (None, 32, 32, 166)  0           batch_normalization_720[0][0]
# __________________________________________________________________________________________________
# conv2d_721 (Conv2D)             (None, 32, 32, 7)    10458       activation_720[0][0]
# __________________________________________________________________________________________________
# dropout_713 (Dropout)           (None, 32, 32, 7)    0           conv2d_721[0][0]
# __________________________________________________________________________________________________
# concatenate_692 (Concatenate)   (None, 32, 32, 173)  0           concatenate_691[0][0]
#                                                                  dropout_713[0][0]
# __________________________________________________________________________________________________
# batch_normalization_721 (BatchN (None, 32, 32, 173)  692         concatenate_692[0][0]
# __________________________________________________________________________________________________
# activation_721 (Activation)     (None, 32, 32, 173)  0           batch_normalization_721[0][0]
# __________________________________________________________________________________________________
# conv2d_722 (Conv2D)             (None, 32, 32, 7)    10899       activation_721[0][0]
# __________________________________________________________________________________________________
# dropout_714 (Dropout)           (None, 32, 32, 7)    0           conv2d_722[0][0]
# __________________________________________________________________________________________________
# concatenate_693 (Concatenate)   (None, 32, 32, 180)  0           concatenate_692[0][0]
#                                                                  dropout_714[0][0]
# __________________________________________________________________________________________________
# batch_normalization_722 (BatchN (None, 32, 32, 180)  720         concatenate_693[0][0]
# __________________________________________________________________________________________________
# activation_722 (Activation)     (None, 32, 32, 180)  0           batch_normalization_722[0][0]
# __________________________________________________________________________________________________
# conv2d_723 (Conv2D)             (None, 32, 32, 7)    11340       activation_722[0][0]
# __________________________________________________________________________________________________
# dropout_715 (Dropout)           (None, 32, 32, 7)    0           conv2d_723[0][0]
# __________________________________________________________________________________________________
# concatenate_694 (Concatenate)   (None, 32, 32, 187)  0           concatenate_693[0][0]
#                                                                  dropout_715[0][0]
# __________________________________________________________________________________________________
# batch_normalization_723 (BatchN (None, 32, 32, 187)  748         concatenate_694[0][0]
# __________________________________________________________________________________________________
# activation_723 (Activation)     (None, 32, 32, 187)  0           batch_normalization_723[0][0]
# __________________________________________________________________________________________________
# conv2d_724 (Conv2D)             (None, 32, 32, 7)    11781       activation_723[0][0]
# __________________________________________________________________________________________________
# dropout_716 (Dropout)           (None, 32, 32, 7)    0           conv2d_724[0][0]
# __________________________________________________________________________________________________
# concatenate_695 (Concatenate)   (None, 32, 32, 194)  0           concatenate_694[0][0]
#                                                                  dropout_716[0][0]
# __________________________________________________________________________________________________
# batch_normalization_724 (BatchN (None, 32, 32, 194)  776         concatenate_695[0][0]
# __________________________________________________________________________________________________
# activation_724 (Activation)     (None, 32, 32, 194)  0           batch_normalization_724[0][0]
# __________________________________________________________________________________________________
# conv2d_725 (Conv2D)             (None, 32, 32, 7)    12222       activation_724[0][0]
# __________________________________________________________________________________________________
# dropout_717 (Dropout)           (None, 32, 32, 7)    0           conv2d_725[0][0]
# __________________________________________________________________________________________________
# concatenate_696 (Concatenate)   (None, 32, 32, 201)  0           concatenate_695[0][0]
#                                                                  dropout_717[0][0]
# __________________________________________________________________________________________________
# batch_normalization_725 (BatchN (None, 32, 32, 201)  804         concatenate_696[0][0]
# __________________________________________________________________________________________________
# activation_725 (Activation)     (None, 32, 32, 201)  0           batch_normalization_725[0][0]
# __________________________________________________________________________________________________
# conv2d_726 (Conv2D)             (None, 32, 32, 7)    12663       activation_725[0][0]
# __________________________________________________________________________________________________
# dropout_718 (Dropout)           (None, 32, 32, 7)    0           conv2d_726[0][0]
# __________________________________________________________________________________________________
# concatenate_697 (Concatenate)   (None, 32, 32, 208)  0           concatenate_696[0][0]
#                                                                  dropout_718[0][0]
# __________________________________________________________________________________________________
# batch_normalization_726 (BatchN (None, 32, 32, 208)  832         concatenate_697[0][0]
# __________________________________________________________________________________________________
# activation_726 (Activation)     (None, 32, 32, 208)  0           batch_normalization_726[0][0]
# __________________________________________________________________________________________________
# conv2d_727 (Conv2D)             (None, 32, 32, 7)    13104       activation_726[0][0]
# __________________________________________________________________________________________________
# dropout_719 (Dropout)           (None, 32, 32, 7)    0           conv2d_727[0][0]
# __________________________________________________________________________________________________
# concatenate_698 (Concatenate)   (None, 32, 32, 215)  0           concatenate_697[0][0]
#                                                                  dropout_719[0][0]
# __________________________________________________________________________________________________
# batch_normalization_727 (BatchN (None, 32, 32, 215)  860         concatenate_698[0][0]
# __________________________________________________________________________________________________
# activation_727 (Activation)     (None, 32, 32, 215)  0           batch_normalization_727[0][0]
# __________________________________________________________________________________________________
# conv2d_728 (Conv2D)             (None, 32, 32, 7)    13545       activation_727[0][0]
# __________________________________________________________________________________________________
# dropout_720 (Dropout)           (None, 32, 32, 7)    0           conv2d_728[0][0]
# __________________________________________________________________________________________________
# concatenate_699 (Concatenate)   (None, 32, 32, 222)  0           concatenate_698[0][0]
#                                                                  dropout_720[0][0]
# __________________________________________________________________________________________________
# batch_normalization_728 (BatchN (None, 32, 32, 222)  888         concatenate_699[0][0]
# __________________________________________________________________________________________________
# activation_728 (Activation)     (None, 32, 32, 222)  0           batch_normalization_728[0][0]
# __________________________________________________________________________________________________
# conv2d_729 (Conv2D)             (None, 32, 32, 7)    13986       activation_728[0][0]
# __________________________________________________________________________________________________
# dropout_721 (Dropout)           (None, 32, 32, 7)    0           conv2d_729[0][0]
# __________________________________________________________________________________________________
# concatenate_700 (Concatenate)   (None, 32, 32, 229)  0           concatenate_699[0][0]
#                                                                  dropout_721[0][0]
# __________________________________________________________________________________________________
# batch_normalization_729 (BatchN (None, 32, 32, 229)  916         concatenate_700[0][0]
# __________________________________________________________________________________________________
# activation_729 (Activation)     (None, 32, 32, 229)  0           batch_normalization_729[0][0]
# __________________________________________________________________________________________________
# conv2d_730 (Conv2D)             (None, 32, 32, 7)    14427       activation_729[0][0]
# __________________________________________________________________________________________________
# dropout_722 (Dropout)           (None, 32, 32, 7)    0           conv2d_730[0][0]
# __________________________________________________________________________________________________
# concatenate_701 (Concatenate)   (None, 32, 32, 236)  0           concatenate_700[0][0]
#                                                                  dropout_722[0][0]
# __________________________________________________________________________________________________
# batch_normalization_730 (BatchN (None, 32, 32, 236)  944         concatenate_701[0][0]
# __________________________________________________________________________________________________
# activation_730 (Activation)     (None, 32, 32, 236)  0           batch_normalization_730[0][0]
# __________________________________________________________________________________________________
# conv2d_731 (Conv2D)             (None, 32, 32, 7)    1652        activation_730[0][0]
# __________________________________________________________________________________________________
# dropout_723 (Dropout)           (None, 32, 32, 7)    0           conv2d_731[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_29 (AveragePo (None, 16, 16, 7)    0           dropout_723[0][0]
# __________________________________________________________________________________________________
# batch_normalization_731 (BatchN (None, 16, 16, 7)    28          average_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# activation_731 (Activation)     (None, 16, 16, 7)    0           batch_normalization_731[0][0]
# __________________________________________________________________________________________________
# conv2d_732 (Conv2D)             (None, 16, 16, 7)    441         activation_731[0][0]
# __________________________________________________________________________________________________
# dropout_724 (Dropout)           (None, 16, 16, 7)    0           conv2d_732[0][0]
# __________________________________________________________________________________________________
# concatenate_702 (Concatenate)   (None, 16, 16, 14)   0           average_pooling2d_29[0][0]
#                                                                  dropout_724[0][0]
# __________________________________________________________________________________________________
# batch_normalization_732 (BatchN (None, 16, 16, 14)   56          concatenate_702[0][0]
# __________________________________________________________________________________________________
# activation_732 (Activation)     (None, 16, 16, 14)   0           batch_normalization_732[0][0]
# __________________________________________________________________________________________________
# conv2d_733 (Conv2D)             (None, 16, 16, 7)    882         activation_732[0][0]
# __________________________________________________________________________________________________
# dropout_725 (Dropout)           (None, 16, 16, 7)    0           conv2d_733[0][0]
# __________________________________________________________________________________________________
# concatenate_703 (Concatenate)   (None, 16, 16, 21)   0           concatenate_702[0][0]
#                                                                  dropout_725[0][0]
# __________________________________________________________________________________________________
# batch_normalization_733 (BatchN (None, 16, 16, 21)   84          concatenate_703[0][0]
# __________________________________________________________________________________________________
# activation_733 (Activation)     (None, 16, 16, 21)   0           batch_normalization_733[0][0]
# __________________________________________________________________________________________________
# conv2d_734 (Conv2D)             (None, 16, 16, 7)    1323        activation_733[0][0]
# __________________________________________________________________________________________________
# dropout_726 (Dropout)           (None, 16, 16, 7)    0           conv2d_734[0][0]
# __________________________________________________________________________________________________
# concatenate_704 (Concatenate)   (None, 16, 16, 28)   0           concatenate_703[0][0]
#                                                                  dropout_726[0][0]
# __________________________________________________________________________________________________
# batch_normalization_734 (BatchN (None, 16, 16, 28)   112         concatenate_704[0][0]
# __________________________________________________________________________________________________
# activation_734 (Activation)     (None, 16, 16, 28)   0           batch_normalization_734[0][0]
# __________________________________________________________________________________________________
# conv2d_735 (Conv2D)             (None, 16, 16, 7)    1764        activation_734[0][0]
# __________________________________________________________________________________________________
# dropout_727 (Dropout)           (None, 16, 16, 7)    0           conv2d_735[0][0]
# __________________________________________________________________________________________________
# concatenate_705 (Concatenate)   (None, 16, 16, 35)   0           concatenate_704[0][0]
#                                                                  dropout_727[0][0]
# __________________________________________________________________________________________________
# batch_normalization_735 (BatchN (None, 16, 16, 35)   140         concatenate_705[0][0]
# __________________________________________________________________________________________________
# activation_735 (Activation)     (None, 16, 16, 35)   0           batch_normalization_735[0][0]
# __________________________________________________________________________________________________
# conv2d_736 (Conv2D)             (None, 16, 16, 7)    2205        activation_735[0][0]
# __________________________________________________________________________________________________
# dropout_728 (Dropout)           (None, 16, 16, 7)    0           conv2d_736[0][0]
# __________________________________________________________________________________________________
# concatenate_706 (Concatenate)   (None, 16, 16, 42)   0           concatenate_705[0][0]
#                                                                  dropout_728[0][0]
# __________________________________________________________________________________________________
# batch_normalization_736 (BatchN (None, 16, 16, 42)   168         concatenate_706[0][0]
# __________________________________________________________________________________________________
# activation_736 (Activation)     (None, 16, 16, 42)   0           batch_normalization_736[0][0]
# __________________________________________________________________________________________________
# conv2d_737 (Conv2D)             (None, 16, 16, 7)    2646        activation_736[0][0]
# __________________________________________________________________________________________________
# dropout_729 (Dropout)           (None, 16, 16, 7)    0           conv2d_737[0][0]
# __________________________________________________________________________________________________
# concatenate_707 (Concatenate)   (None, 16, 16, 49)   0           concatenate_706[0][0]
#                                                                  dropout_729[0][0]
# __________________________________________________________________________________________________
# batch_normalization_737 (BatchN (None, 16, 16, 49)   196         concatenate_707[0][0]
# __________________________________________________________________________________________________
# activation_737 (Activation)     (None, 16, 16, 49)   0           batch_normalization_737[0][0]
# __________________________________________________________________________________________________
# conv2d_738 (Conv2D)             (None, 16, 16, 7)    3087        activation_737[0][0]
# __________________________________________________________________________________________________
# dropout_730 (Dropout)           (None, 16, 16, 7)    0           conv2d_738[0][0]
# __________________________________________________________________________________________________
# concatenate_708 (Concatenate)   (None, 16, 16, 56)   0           concatenate_707[0][0]
#                                                                  dropout_730[0][0]
# __________________________________________________________________________________________________
# batch_normalization_738 (BatchN (None, 16, 16, 56)   224         concatenate_708[0][0]
# __________________________________________________________________________________________________
# activation_738 (Activation)     (None, 16, 16, 56)   0           batch_normalization_738[0][0]
# __________________________________________________________________________________________________
# conv2d_739 (Conv2D)             (None, 16, 16, 7)    3528        activation_738[0][0]
# __________________________________________________________________________________________________
# dropout_731 (Dropout)           (None, 16, 16, 7)    0           conv2d_739[0][0]
# __________________________________________________________________________________________________
# concatenate_709 (Concatenate)   (None, 16, 16, 63)   0           concatenate_708[0][0]
#                                                                  dropout_731[0][0]
# __________________________________________________________________________________________________
# batch_normalization_739 (BatchN (None, 16, 16, 63)   252         concatenate_709[0][0]
# __________________________________________________________________________________________________
# activation_739 (Activation)     (None, 16, 16, 63)   0           batch_normalization_739[0][0]
# __________________________________________________________________________________________________
# conv2d_740 (Conv2D)             (None, 16, 16, 7)    3969        activation_739[0][0]
# __________________________________________________________________________________________________
# dropout_732 (Dropout)           (None, 16, 16, 7)    0           conv2d_740[0][0]
# __________________________________________________________________________________________________
# concatenate_710 (Concatenate)   (None, 16, 16, 70)   0           concatenate_709[0][0]
#                                                                  dropout_732[0][0]
# __________________________________________________________________________________________________
# batch_normalization_740 (BatchN (None, 16, 16, 70)   280         concatenate_710[0][0]
# __________________________________________________________________________________________________
# activation_740 (Activation)     (None, 16, 16, 70)   0           batch_normalization_740[0][0]
# __________________________________________________________________________________________________
# conv2d_741 (Conv2D)             (None, 16, 16, 7)    4410        activation_740[0][0]
# __________________________________________________________________________________________________
# dropout_733 (Dropout)           (None, 16, 16, 7)    0           conv2d_741[0][0]
# __________________________________________________________________________________________________
# concatenate_711 (Concatenate)   (None, 16, 16, 77)   0           concatenate_710[0][0]
#                                                                  dropout_733[0][0]
# __________________________________________________________________________________________________
# batch_normalization_741 (BatchN (None, 16, 16, 77)   308         concatenate_711[0][0]
# __________________________________________________________________________________________________
# activation_741 (Activation)     (None, 16, 16, 77)   0           batch_normalization_741[0][0]
# __________________________________________________________________________________________________
# conv2d_742 (Conv2D)             (None, 16, 16, 7)    4851        activation_741[0][0]
# ...
# conv2d_796 (Conv2D)             (None, 8, 8, 7)      14112       activation_795[0][0]
# __________________________________________________________________________________________________
# dropout_788 (Dropout)           (None, 8, 8, 7)      0           conv2d_796[0][0]
# __________________________________________________________________________________________________
# concatenate_765 (Concatenate)   (None, 8, 8, 231)    0           concatenate_764[0][0]
#                                                                  dropout_788[0][0]
# __________________________________________________________________________________________________
# batch_normalization_796 (BatchN (None, 8, 8, 231)    924         concatenate_765[0][0]
# __________________________________________________________________________________________________
# activation_796 (Activation)     (None, 8, 8, 231)    0           batch_normalization_796[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 8, 8, 7)      1617        activation_796[0][0]
# __________________________________________________________________________________________________
# dropout_789 (Dropout)           (None, 8, 8, 7)      0           conv2d_797[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_31 (AveragePo (None, 4, 4, 7)      0           dropout_789[0][0]
# __________________________________________________________________________________________________
# batch_normalization_797 (BatchN (None, 4, 4, 7)      28          average_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# activation_797 (Activation)     (None, 4, 4, 7)      0           batch_normalization_797[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 4, 4, 7)      441         activation_797[0][0]
# __________________________________________________________________________________________________
# dropout_790 (Dropout)           (None, 4, 4, 7)      0           conv2d_798[0][0]
# __________________________________________________________________________________________________
# concatenate_766 (Concatenate)   (None, 4, 4, 14)     0           average_pooling2d_31[0][0]
#                                                                  dropout_790[0][0]
# __________________________________________________________________________________________________
# batch_normalization_798 (BatchN (None, 4, 4, 14)     56          concatenate_766[0][0]
# __________________________________________________________________________________________________
# activation_798 (Activation)     (None, 4, 4, 14)     0           batch_normalization_798[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 4, 4, 7)      882         activation_798[0][0]
# __________________________________________________________________________________________________
# dropout_791 (Dropout)           (None, 4, 4, 7)      0           conv2d_799[0][0]
# __________________________________________________________________________________________________
# concatenate_767 (Concatenate)   (None, 4, 4, 21)     0           concatenate_766[0][0]
#                                                                  dropout_791[0][0]
# __________________________________________________________________________________________________
# batch_normalization_799 (BatchN (None, 4, 4, 21)     84          concatenate_767[0][0]
# __________________________________________________________________________________________________
# activation_799 (Activation)     (None, 4, 4, 21)     0           batch_normalization_799[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 4, 4, 7)      1323        activation_799[0][0]
# __________________________________________________________________________________________________
# dropout_792 (Dropout)           (None, 4, 4, 7)      0           conv2d_800[0][0]
# __________________________________________________________________________________________________
# concatenate_768 (Concatenate)   (None, 4, 4, 28)     0           concatenate_767[0][0]
#                                                                  dropout_792[0][0]
# __________________________________________________________________________________________________
# batch_normalization_800 (BatchN (None, 4, 4, 28)     112         concatenate_768[0][0]
# __________________________________________________________________________________________________
# activation_800 (Activation)     (None, 4, 4, 28)     0           batch_normalization_800[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 4, 4, 7)      1764        activation_800[0][0]
# __________________________________________________________________________________________________
# dropout_793 (Dropout)           (None, 4, 4, 7)      0           conv2d_801[0][0]
# __________________________________________________________________________________________________
# concatenate_769 (Concatenate)   (None, 4, 4, 35)     0           concatenate_768[0][0]
#                                                                  dropout_793[0][0]
# __________________________________________________________________________________________________
# batch_normalization_801 (BatchN (None, 4, 4, 35)     140         concatenate_769[0][0]
# __________________________________________________________________________________________________
# activation_801 (Activation)     (None, 4, 4, 35)     0           batch_normalization_801[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 4, 4, 7)      2205        activation_801[0][0]
# __________________________________________________________________________________________________
# dropout_794 (Dropout)           (None, 4, 4, 7)      0           conv2d_802[0][0]
# __________________________________________________________________________________________________
# concatenate_770 (Concatenate)   (None, 4, 4, 42)     0           concatenate_769[0][0]
#                                                                  dropout_794[0][0]
# __________________________________________________________________________________________________
# batch_normalization_802 (BatchN (None, 4, 4, 42)     168         concatenate_770[0][0]
# __________________________________________________________________________________________________
# activation_802 (Activation)     (None, 4, 4, 42)     0           batch_normalization_802[0][0]
# __________________________________________________________________________________________________
# conv2d_803 (Conv2D)             (None, 4, 4, 7)      2646        activation_802[0][0]
# __________________________________________________________________________________________________
# dropout_795 (Dropout)           (None, 4, 4, 7)      0           conv2d_803[0][0]
# __________________________________________________________________________________________________
# concatenate_771 (Concatenate)   (None, 4, 4, 49)     0           concatenate_770[0][0]
#                                                                  dropout_795[0][0]
# __________________________________________________________________________________________________
# batch_normalization_803 (BatchN (None, 4, 4, 49)     196         concatenate_771[0][0]
# __________________________________________________________________________________________________
# activation_803 (Activation)     (None, 4, 4, 49)     0           batch_normalization_803[0][0]
# __________________________________________________________________________________________________
# conv2d_804 (Conv2D)             (None, 4, 4, 7)      3087        activation_803[0][0]
# __________________________________________________________________________________________________
# dropout_796 (Dropout)           (None, 4, 4, 7)      0           conv2d_804[0][0]
# __________________________________________________________________________________________________
# concatenate_772 (Concatenate)   (None, 4, 4, 56)     0           concatenate_771[0][0]
#                                                                  dropout_796[0][0]
# __________________________________________________________________________________________________
# batch_normalization_804 (BatchN (None, 4, 4, 56)     224         concatenate_772[0][0]
# __________________________________________________________________________________________________
# activation_804 (Activation)     (None, 4, 4, 56)     0           batch_normalization_804[0][0]
# __________________________________________________________________________________________________
# conv2d_805 (Conv2D)             (None, 4, 4, 7)      3528        activation_804[0][0]
# __________________________________________________________________________________________________
# dropout_797 (Dropout)           (None, 4, 4, 7)      0           conv2d_805[0][0]
# __________________________________________________________________________________________________
# concatenate_773 (Concatenate)   (None, 4, 4, 63)     0           concatenate_772[0][0]
#                                                                  dropout_797[0][0]
# __________________________________________________________________________________________________
# batch_normalization_805 (BatchN (None, 4, 4, 63)     252         concatenate_773[0][0]
# __________________________________________________________________________________________________
# activation_805 (Activation)     (None, 4, 4, 63)     0           batch_normalization_805[0][0]
# __________________________________________________________________________________________________
# conv2d_806 (Conv2D)             (None, 4, 4, 7)      3969        activation_805[0][0]
# __________________________________________________________________________________________________
# dropout_798 (Dropout)           (None, 4, 4, 7)      0           conv2d_806[0][0]
# __________________________________________________________________________________________________
# concatenate_774 (Concatenate)   (None, 4, 4, 70)     0           concatenate_773[0][0]
#                                                                  dropout_798[0][0]
# __________________________________________________________________________________________________
# batch_normalization_806 (BatchN (None, 4, 4, 70)     280         concatenate_774[0][0]
# __________________________________________________________________________________________________
# activation_806 (Activation)     (None, 4, 4, 70)     0           batch_normalization_806[0][0]
# __________________________________________________________________________________________________
# conv2d_807 (Conv2D)             (None, 4, 4, 7)      4410        activation_806[0][0]
# __________________________________________________________________________________________________
# dropout_799 (Dropout)           (None, 4, 4, 7)      0           conv2d_807[0][0]
# __________________________________________________________________________________________________
# concatenate_775 (Concatenate)   (None, 4, 4, 77)     0           concatenate_774[0][0]
#                                                                  dropout_799[0][0]
# __________________________________________________________________________________________________
# batch_normalization_807 (BatchN (None, 4, 4, 77)     308         concatenate_775[0][0]
# __________________________________________________________________________________________________
# activation_807 (Activation)     (None, 4, 4, 77)     0           batch_normalization_807[0][0]
# __________________________________________________________________________________________________
# conv2d_808 (Conv2D)             (None, 4, 4, 7)      4851        activation_807[0][0]
# __________________________________________________________________________________________________
# dropout_800 (Dropout)           (None, 4, 4, 7)      0           conv2d_808[0][0]
# __________________________________________________________________________________________________
# concatenate_776 (Concatenate)   (None, 4, 4, 84)     0           concatenate_775[0][0]
#                                                                  dropout_800[0][0]
# __________________________________________________________________________________________________
# batch_normalization_808 (BatchN (None, 4, 4, 84)     336         concatenate_776[0][0]
# __________________________________________________________________________________________________
# activation_808 (Activation)     (None, 4, 4, 84)     0           batch_normalization_808[0][0]
# __________________________________________________________________________________________________
# conv2d_809 (Conv2D)             (None, 4, 4, 7)      5292        activation_808[0][0]
# __________________________________________________________________________________________________
# dropout_801 (Dropout)           (None, 4, 4, 7)      0           conv2d_809[0][0]
# __________________________________________________________________________________________________
# concatenate_777 (Concatenate)   (None, 4, 4, 91)     0           concatenate_776[0][0]
#                                                                  dropout_801[0][0]
# __________________________________________________________________________________________________
# batch_normalization_809 (BatchN (None, 4, 4, 91)     364         concatenate_777[0][0]
# __________________________________________________________________________________________________
# activation_809 (Activation)     (None, 4, 4, 91)     0           batch_normalization_809[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_32 (AveragePo (None, 2, 2, 91)     0           activation_809[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 364)          0           average_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 10)           3650        flatten_8[0][0]
# ==================================================================================================
# Total params: 802,214
# Trainable params: 777,048
# Non-trainable params: 25,166
# __________________________________________________________________________________________________

# %%
#train model
i+=1
h=model_large1.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_epochs[i][0],epochs=model_epochs[i][1], callbacks=callbacks, validation_data=(x_test, y_test))
hist.append(h)
model_large1.save(model_file)
print("Saved model to disk")
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 608s 12ms/step - loss: 1.9677 - acc: 0.2709 - val_loss: 1.7646 - val_acc: 0.3575
# Epoch 2/50
# 50000/50000 [==============================] - 511s 10ms/step - loss: 1.7459 - acc: 0.3554 - val_loss: 1.7766 - val_acc: 0.3700
#
# Epoch 00002: val_acc improved from -inf to 0.37000, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.02-0.37.h5
# Epoch 3/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.6336 - acc: 0.4023 - val_loss: 2.6920 - val_acc: 0.2574
# Epoch 4/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.5405 - acc: 0.4377 - val_loss: 1.7699 - val_acc: 0.4071
#
# Epoch 00004: val_acc improved from 0.37000 to 0.40710, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.04-0.41.h5
# Epoch 5/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.4671 - acc: 0.4641 - val_loss: 1.5887 - val_acc: 0.4754
# Epoch 6/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.4001 - acc: 0.4906 - val_loss: 1.6663 - val_acc: 0.4838
#
# Epoch 00006: val_acc improved from 0.40710 to 0.48380, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.06-0.48.h5
# Epoch 7/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 1.3493 - acc: 0.5123 - val_loss: 1.7530 - val_acc: 0.4893
# Epoch 8/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.3036 - acc: 0.5300 - val_loss: 1.6461 - val_acc: 0.4830
#
# Epoch 00008: val_acc did not improve from 0.48380
# Epoch 9/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.2639 - acc: 0.5432 - val_loss: 1.6140 - val_acc: 0.5219
# Epoch 10/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.2295 - acc: 0.5609 - val_loss: 1.3726 - val_acc: 0.5769
#
# Epoch 00010: val_acc improved from 0.48380 to 0.57690, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.10-0.58.h5
# Epoch 11/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.1964 - acc: 0.5711 - val_loss: 1.8529 - val_acc: 0.5213
# Epoch 12/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.1684 - acc: 0.5814 - val_loss: 1.4628 - val_acc: 0.5640
#
# Epoch 00012: val_acc did not improve from 0.57690
# Epoch 13/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.1366 - acc: 0.5934 - val_loss: 1.5415 - val_acc: 0.5731
# Epoch 14/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.1188 - acc: 0.6040 - val_loss: 1.6466 - val_acc: 0.5599
#
# Epoch 00014: val_acc did not improve from 0.57690
# Epoch 15/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 1.0920 - acc: 0.6115 - val_loss: 1.2912 - val_acc: 0.6262
# Epoch 16/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.0686 - acc: 0.6203 - val_loss: 2.0874 - val_acc: 0.5257
#
# Epoch 00016: val_acc did not improve from 0.57690
# Epoch 17/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.0522 - acc: 0.6269 - val_loss: 2.4749 - val_acc: 0.4766
# Epoch 18/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 1.0285 - acc: 0.6361 - val_loss: 1.6462 - val_acc: 0.5770
#
# Epoch 00018: val_acc improved from 0.57690 to 0.57700, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.18-0.58.h5
# Epoch 19/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 1.0103 - acc: 0.6413 - val_loss: 1.3804 - val_acc: 0.6118
# Epoch 20/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.9930 - acc: 0.6486 - val_loss: 1.7347 - val_acc: 0.5599
#
# Epoch 00020: val_acc did not improve from 0.57700
# Epoch 21/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.9758 - acc: 0.6523 - val_loss: 1.4001 - val_acc: 0.6284
# Epoch 22/50
# 50000/50000 [==============================] - 514s 10ms/step - loss: 0.9603 - acc: 0.6606 - val_loss: 2.0491 - val_acc: 0.5398
#
# Epoch 00022: val_acc did not improve from 0.57700
# Epoch 23/50
# 50000/50000 [==============================] - 515s 10ms/step - loss: 0.9466 - acc: 0.6676 - val_loss: 1.6524 - val_acc: 0.5843
# Epoch 24/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.9312 - acc: 0.6713 - val_loss: 2.6872 - val_acc: 0.4818
#
# Epoch 00024: val_acc did not improve from 0.57700
# Epoch 25/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.9145 - acc: 0.6777 - val_loss: 1.2435 - val_acc: 0.6557
# Epoch 26/50
# 50000/50000 [==============================] - 514s 10ms/step - loss: 0.8998 - acc: 0.6817 - val_loss: 1.3980 - val_acc: 0.6340
#
# Epoch 00026: val_acc improved from 0.57700 to 0.63400, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.26-0.63.h5
# Epoch 27/50
# 50000/50000 [==============================] - 514s 10ms/step - loss: 0.8934 - acc: 0.6850 - val_loss: 1.2212 - val_acc: 0.6633
# Epoch 28/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.8783 - acc: 0.6905 - val_loss: 1.8754 - val_acc: 0.5661
#
# Epoch 00028: val_acc did not improve from 0.63400
# Epoch 29/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.8668 - acc: 0.6920 - val_loss: 1.7622 - val_acc: 0.5973
# Epoch 30/50
# 50000/50000 [==============================] - 514s 10ms/step - loss: 0.8565 - acc: 0.6992 - val_loss: 1.7065 - val_acc: 0.5925
#
# Epoch 00030: val_acc did not improve from 0.63400
# Epoch 31/50
# 50000/50000 [==============================] - 514s 10ms/step - loss: 0.8428 - acc: 0.7003 - val_loss: 1.9798 - val_acc: 0.5771
# Epoch 32/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.8322 - acc: 0.7069 - val_loss: 1.3171 - val_acc: 0.6612
#
# Epoch 00032: val_acc improved from 0.63400 to 0.66120, saving model to /content/gdrive/My Drive/Colab Notebooks/weights/large_weights.32-0.66.h5
# Epoch 33/50
# 50000/50000 [==============================] - 515s 10ms/step - loss: 0.8215 - acc: 0.7077 - val_loss: 1.7647 - val_acc: 0.5975
# Epoch 34/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.8149 - acc: 0.7118 - val_loss: 1.2872 - val_acc: 0.6539
#
# Epoch 00034: val_acc did not improve from 0.66120
# Epoch 35/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.7998 - acc: 0.7196 - val_loss: 1.2513 - val_acc: 0.6744
# Epoch 36/50
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.7892 - acc: 0.7223 - val_loss: 1.6220 - val_acc: 0.6224
#
# Epoch 00036: val_acc did not improve from 0.66120
# Epoch 37/50
# 50000/50000 [==============================] - 512s 10ms/step - loss: 0.7845 - acc: 0.7256 - val_loss: 1.3468 - val_acc: 0.6650
# Epoch 38/50
# 50000/50000 [==============================] - 511s 10ms/step - loss: 0.7749 - acc: 0.7264 - val_loss: 2.0947 - val_acc: 0.5741
#
# Epoch 00038: val_acc did not improve from 0.66120
# Epoch 39/50
# 50000/50000 [==============================] - 511s 10ms/step - loss: 0.7697 - acc: 0.7296 - val_loss: 1.6651 - val_acc: 0.6231
# Epoch 40/50
# 24064/50000 [=============>................] - ETA: 4:09 - loss: 0.7547 - acc: 0.7319

# %%
# dropout_rate = 0.2

# model_large2=create_model(x_train.shape[1:],num_layers=layers_large)
# model_large2.set_weights(model_large1.get_weights())
# del model_large1
#callbacks
model_large2=model_large1
model_checkpointer=ModelCheckpoint(weights_dir+'large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
model_large2.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=SGD(lr=0.01, decay=1e-4, momentum=0.9, nesterov=True))

callbacks = [ model_checkpointer]

#train model
i+=1
h=model_large2.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_epochs[i][0],epochs=model_epochs[i][1], callbacks=callbacks,validation_data=(x_test, y_test))
hist.append(h)
model_large2.save(model_file)
print("Saved model to disk")

# %%
# model_checkpointer=ModelCheckpoint(weights_dir+'large_weights.{epoch:02d}-{val_acc:.2f}.h5', monitor='val_acc',verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=2)
# clr = CyclicLR(base_lr=0.001, max_lr=0.006,step_size=6*(len(y_train)/batch_size),mode='triangular')

# callbacks = [clr, model_checkpointer]
# model_large_2=load_model('large_weights.112-0.87.h5')

# %%
# #train model
i+=1
# h=model_large_2.fit(x_train, y_train, batch_size=batch_size, verbose=1,initial_epoch=model_epochs[i][0],epochs=model_epochs[i][1], callbacks=callbacks,validation_data=(x_test, y_test))
# hist.append(h)
# model_large2.save(model_file)
# print("Saved model to disk")

# %%
# Test the model
score = model_large2.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
print('====================END OF LARGER MODEL====================')
